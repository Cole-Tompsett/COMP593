# %% [markdown]
# <a href="https://colab.research.google.com/github/Cole-Tompsett/COMP593/blob/main/WEEK_3_WORKING_WITH_DATABASES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LAB 3: WORKING WITH DATABASES

# %% [markdown]
# ## Introduction
#
# During this lab, we will experiment with using a few different libararies and modules to connect to and interact with an SQLite database. After creating and configuring our testing database, we will populate it with Fake data and run some queries to see what kind of information we can retreive. For context, we will be creating RSSN, the "Really Simple Social Network".

# %% [markdown]
# ## Creating a SQLite Database
#
# We will be utilizing the `sqlite3` library to create our database file, as it offers the convienience of creating our database file automatically in the event that it cannot find an existing file at the path specified.
#
# **Before you run the below code:**
# On the left of the notebook, select the file folder icon. Then, after you run the code block, you should be able to observe the creation of the database file. If it doesn't appear, try clicking the "Refresh" button above the list of folders.

# %%
import sqlite3

#When we retreive a Connection object, a new database will be created for us if it doesn't already exist. 
myConnection = sqlite3.connect('social_network.db')
print(sqlite3.version)
# Out:
# 2.6.0

# %% [markdown]
# ## Creating a Table

# %% [markdown]
# We'll use the below code to create a table called `people` within our database.

# %%
import sqlite3

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Let's define the SQL Query we will use to create our first table:
createPeopleTable = """ CREATE TABLE IF NOT EXISTS people (
                          id integer PRIMARY KEY,
                          name text NOT NULL,
                          email text NOT NULL,
                          address text NOT NULL,
                          city text NOT NULL,
                          province text NOT NULL,
                          country text NOT NULL,
                          phone text,
                          bio text,
                          dob date NOT NULL,
                          heatmap integer,
                          created_at datetime NOT NULL,
                          updated_at datetime NOT NULL,
                          ipv4 text
                        );"""

#Now that we have the string to create our table,
#Cursor objects have an execute() method which will accept an SQL string and perform the operations described.

myCursor.execute(createPeopleTable)

#We can confirm if our table was created successfully by running the following SQL Query
#pragma_table_info is an internal SQLite function that will retun information about a table
myCursor.execute("SELECT group_concat(name, ', ') FROM pragma_table_info('people')")
print(myCursor.fetchone())

#We use to the commit() method on the database Connection object to persist our changes
myConnection.commit()

#It is always a good idea to close a connection when it will no longer be used
myConnection.close()
# Out:
# ('id, name, email, address, city, province, country, phone, bio, dob, heatmap, created_at, updated_at, ipv4',)

# %% [markdown]
# If you received a tuple containing the names of the columns, awesome! We have successfully created our database table.
# ```
# ('id, name, email, address, city, province, country, phone, bio, created_at, updated_at',)
# ```
#
# Run the below code block to add our first entry.

# %%
import sqlite3
from pprint import pprint #Outputs data in a slightly easier to read format
from datetime import datetime #For generating dates and times

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Let's define the SQL Query we will use to create our first entry:
addPersonQuery = """INSERT INTO people (name, 
                      email, 
                      address, 
                      city, 
                      province, 
                      country, 
                      phone, 
                      bio,
                      dob,
                      heatmap,
                      created_at, 
                      updated_at, 
                      ipv4)
                  VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?);"""

"""
The ?'s are placeholders that we can fill in when we use the execute() method.
This is really handy for code reuse, as we can pass those values are variables in a tuple
Instead of hard coding them into the statement.
"""

myPerson = ("John Doe", 
            "johndoe@anon.null", 
            "123 Fake St.", 
            "Fakesville", 
            "Fakesdom", 
            "Fakopolis", 
            None, 
            None,
            "1967-09-12",
            0,
            datetime.now(), 
            datetime.now(),
            None)

myCursor.execute(addPersonQuery, myPerson)

#We can confirm if our table was created successfully by running the following SQL Query
#pragma_table_info is an internal SQLite function that will retun information about a table
myCursor.execute("SELECT * FROM people")
pprint(myCursor.fetchall())

# If you run this code block a few times, you will see that you only have 1 entry,
# If you uncomment the below lines and run the block a few more times, you will begin to see multiple entries.
myConnection.commit()
myConnection.close()
# Out:
# [(1,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2022-02-20 18:34:38.938936',
#   '2022-02-20 18:34:38.938949',
#   None)]

# %% [markdown]
# # Lab Submission

# %% [markdown]
# We're going to build our experience with working with Libraries and examining documentation by populating our 'People' table with data provided to us by the `Faker` library. `Faker` is used to generate fake data and is very helpful for the rapid generation of databases for the purposes of testing. Run the two blocks below to install faker and get an idea of what it can do.

# %%
# !pip install faker
# Out:
# Requirement already satisfied: faker in /usr/local/lib/python3.7/dist-packages (13.0.0)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.7/dist-packages (from faker) (2.8.2)
# Requirement already satisfied: typing-extensions>=3.10.0.2 in /usr/local/lib/python3.7/dist-packages (from faker) (3.10.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.4->faker) (1.15.0)

# %%
from faker import Faker

fake = Faker()

for _ in range(10):
  print('{} || {}'.format( fake.name(), fake.job() ) )
# Out:
# Deborah Reed || Stage manager
# Damon Stark || Chartered accountant
# Robert Yang || Air broker
# Jacqueline Washington || Forest/woodland manager
# Theresa Hall || Community pharmacist
# Sarah Singh || Landscape architect
# Michael Nguyen || Therapist, drama
# Kelly Acosta || Health visitor
# Courtney Acosta || Politician's assistant
# Amy West || Clinical molecular geneticist

# %% [markdown]
# Very cool! Faker has tons of `providers` that can all be used to populate fake data. The [list of providers](https://faker.readthedocs.io/en/stable/providers.html) in the Faker documentation will help you fill out the columns for our People table.
#
# The goal of this script is to populate the people table with 1000 entries, with the following constraints:
#
# 1. The `heatmap` column must contain a random number between `999` and `2500`
# 2. The `created_at` and `updated_at` columns must use the `datetime` object (see examples above)
# 2. Use `Faker` to generate all other fields.
#
# *Hint: Each of the methods contained in the provider can be called directly from the base Faker object, for example, one can call the `file_name()` method from `faker.providers.file` by calling `Faker().file_name()`*

# %%
import sqlite3
from faker import Faker
from pprint import pprint
from datetime import datetime #For generating dates and times
#Don't forget to import the module to generate random numbers!

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#This is the same syntax as the above example:
addPersonQuery = """INSERT INTO people (name, 
                      email, 
                      address, 
                      city, 
                      province, 
                      country, 
                      phone, 
                      bio,
                      dob,
                      heatmap,
                      created_at, 
                      updated_at, 
                      ipv4)
                  VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?);"""

#creating an entry in the database for a new person 1000 times
fake = Faker("en_CA")
for person in range(1000):
  myPerson= (fake.name(), 
              fake.ascii_email(), 
              fake.address(), 
              fake.city(), 
              fake.administrative_unit(),
              fake.country(),
              fake.phone_number(),
              fake.sentence(nb_words= 7),
              fake.date_of_birth(),
              fake.random_int(min=999, max =2500),
              datetime.now(), 
              datetime.now(),
              fake.ipv4())

  myCursor.execute(addPersonQuery, myPerson)


#displays all the information in the database to the console
myCursor.execute("SELECT * FROM people")
pprint(myCursor.fetchall())

#commits queries to the batabase and close the connection we had
myConnection.commit()
myConnection.close()
# Out:
# Streaming output truncated to the last 5000 lines.
#   '2022-02-20 18:36:04.234859',
#   '210.149.43.64'),
#  (645,
#   'Brett Moore',
#   'smithspencer@gmail.com',
#   '53973 Martin Oval\nNew Veronica, NT L8J1K1',
#   'Stevensville',
#   'New Brunswick',
#   'Kazakhstan',
#   '1 (911) 230-7674',
#   'Occaecati natus explicabo.',
#   '1971-06-04',
#   1583,
#   '2022-02-20 18:36:04.235791',
#   '2022-02-20 18:36:04.235792',
#   '189.84.179.208'),
#  (646,
#   'Sarah Miranda',
#   'lwatson@riddle.com',
#   '2735 Kennedy Stream Suite 553\nLake Markville, ON B9L 2R7',
#   'East Josephside',
#   'Nova Scotia',
#   'Sweden',
#   '+1 (215) 001-1481',
#   'Dignissimos dolorem officia.',
#   '2006-01-18',
#   2283,
#   '2022-02-20 18:36:04.237022',
#   '2022-02-20 18:36:04.237023',
#   '171.46.81.204'),
#  (647,
#   'Yvonne Nichols',
#   'alexander69@baker-floyd.com',
#   '94527 Sara Gateway Suite 866\nWest Haleybury, ON X3X3A6',
#   'West Christopherbury',
#   'Quebec',
#   'Mayotte',
#   '299 394 3862',
#   'Molestias repudiandae.',
#   '1986-02-24',
#   1839,
#   '2022-02-20 18:36:04.238035',
#   '2022-02-20 18:36:04.238037',
#   '51.29.91.169'),
#  (648,
#   'Lauren Vasquez',
#   'anthony65@hotmail.com',
#   '33179 Yvonne Burg\nMistyborough, SK R5H 8G2',
#   'Jacobstown',
#   'Manitoba',
#   'Faroe Islands',
#   '1 (257) 458-7845',
#   'Ea doloribus neque aperiam.',
#   '1990-04-23',
#   2247,
#   '2022-02-20 18:36:04.238856',
#   '2022-02-20 18:36:04.238857',
#   '123.104.65.66'),
#  (649,
#   'Jeffrey Carr',
#   'lfarley@chavez-richardson.com',
#   '89103 Greg Plaza\nCastillomouth, NS K7B 3K2',
#   'New Traceyborough',
#   'Newfoundland and Labrador',
#   'Ethiopia',
#   '931-791-3488',
#   'Quisquam voluptates.',
#   '2002-01-30',
#   2109,
#   '2022-02-20 18:36:04.239888',
#   '2022-02-20 18:36:04.239889',
#   '215.226.17.79'),
#  (650,
#   'Andrea Diaz',
#   'estradaamanda@hotmail.com',
#   '856 Christopher Gardens\nSouth Benjamin, BC L2P2A4',
#   'Singletonville',
#   'New Brunswick',
#   'Ghana',
#   '907.404.6361',
#   'Eum aspernatur asperiores.',
#   '1995-02-21',
#   1744,
#   '2022-02-20 18:36:04.240782',
#   '2022-02-20 18:36:04.240783',
#   '55.14.215.242'),
#  (651,
#   'Travis Stephens',
#   'diaznicole@diaz-byrd.info',
#   '37874 Isaac Hollow Suite 494\nWest Amandaport, MB E5P9L6',
#   'West Ann',
#   'Northwest Territories',
#   'British Virgin Islands',
#   '1 (693) 625-6843',
#   'Facilis explicabo esse.',
#   '1985-10-12',
#   2490,
#   '2022-02-20 18:36:04.241866',
#   '2022-02-20 18:36:04.241868',
#   '192.91.202.184'),
#  (652,
#   'Ryan Edwards',
#   'heather41@gmail.com',
#   '83639 Kevin Lodge\nEast Victoria, PE H3K 5L6',
#   'Perezhaven',
#   'Prince Edward Island',
#   'Mali',
#   '(252) 241-9687',
#   'Iusto corporis soluta.',
#   '2020-03-03',
#   1136,
#   '2022-02-20 18:36:04.242902',
#   '2022-02-20 18:36:04.242903',
#   '13.13.246.222'),
#  (653,
#   'Linda Lewis',
#   'vickiematthews@hotmail.com',
#   '2047 Robertson Brook Apt. 818\nMarkland, YT K1A 9G3',
#   'South Christophermouth',
#   'Northwest Territories',
#   'Dominica',
#   '347-581-9466',
#   'Voluptates natus quod.',
#   '1925-11-02',
#   1135,
#   '2022-02-20 18:36:04.243839',
#   '2022-02-20 18:36:04.243841',
#   '176.83.207.79'),
#  (654,
#   'Tyler Faulkner',
#   'christine94@hotmail.com',
#   '2009 Sutton Corner\nWest Andrea, NL L4E 2X5',
#   'East Larry',
#   'Quebec',
#   'Saint Martin',
#   '150-671-3779 x777',
#   'Vitae a.',
#   '2013-01-15',
#   1688,
#   '2022-02-20 18:36:04.244696',
#   '2022-02-20 18:36:04.244697',
#   '189.79.21.200'),
#  (655,
#   'Gregory Rodriguez',
#   'rodriguezmelissa@garcia.com',
#   '40737 Zachary Turnpike Apt. 553\nLisaberg, NL R6K 9L3',
#   'Port Tristan',
#   'Newfoundland and Labrador',
#   'Central African Republic',
#   '1-235-319-4939',
#   'Rem blanditiis dolorum ducimus.',
#   '1919-11-30',
#   2302,
#   '2022-02-20 18:36:04.245705',
#   '2022-02-20 18:36:04.245706',
#   '63.152.112.173'),
#  (656,
#   'Kimberly Rodriguez',
#   'brianjohnson@yahoo.com',
#   '87108 Kevin Tunnel\nRobertsland, MB A1A2N1',
#   'Prestonmouth',
#   'Nunavut',
#   'Afghanistan',
#   '384.579.7030',
#   'Voluptates quaerat repudiandae.',
#   '1922-02-19',
#   1576,
#   '2022-02-20 18:36:04.246627',
#   '2022-02-20 18:36:04.246628',
#   '107.13.142.149'),
#  (657,
#   'Andrea Espinoza',
#   'vgordon@hotmail.com',
#   '919 Logan Pine\nNew Jorgeland, ON C4V 4H6',
#   'Berryville',
#   'New Brunswick',
#   'Venezuela',
#   '607.366.8497',
#   'Nemo.',
#   '1919-07-04',
#   1824,
#   '2022-02-20 18:36:04.247482',
#   '2022-02-20 18:36:04.247483',
#   '88.146.125.27'),
#  (658,
#   'Tonya Gregory',
#   'whitney29@gmail.com',
#   '54511 Massey Village\nElizabethside, QC H4X 2S3',
#   'Stanleyburgh',
#   'New Brunswick',
#   'Maldives',
#   '708 572 7852',
#   'Molestiae iusto.',
#   '1920-07-24',
#   2026,
#   '2022-02-20 18:36:04.248329',
#   '2022-02-20 18:36:04.248331',
#   '185.70.128.160'),
#  (659,
#   'Kristopher Clark',
#   'ewebb@hotmail.com',
#   '141 Laura Estates Suite 761\nLozanoport, AB A6M6L8',
#   'New Amberview',
#   'Prince Edward Island',
#   'Central African Republic',
#   '1-170-585-9365',
#   'Eligendi mollitia et.',
#   '1947-09-25',
#   1074,
#   '2022-02-20 18:36:04.249909',
#   '2022-02-20 18:36:04.249910',
#   '166.109.197.22'),
#  (660,
#   'Michael Norris',
#   'cartermario@hotmail.com',
#   '726 Cody Club\nAnthonyfurt, NT S2J 6N8',
#   'Edwardsstad',
#   'Alberta',
#   'Gambia',
#   '199-724-2812',
#   'Quisquam temporibus.',
#   '1957-09-08',
#   1304,
#   '2022-02-20 18:36:04.250980',
#   '2022-02-20 18:36:04.250981',
#   '56.2.122.95'),
#  (661,
#   'Benjamin Payne',
#   'rlee@hotmail.com',
#   '9366 Angela Trace\nCruzton, QC V7E 2H8',
#   'Toddville',
#   'Nunavut',
#   'Costa Rica',
#   '232-538-1732',
#   'Qui non velit.',
#   '1937-08-14',
#   2216,
#   '2022-02-20 18:36:04.252478',
#   '2022-02-20 18:36:04.252479',
#   '104.121.114.240'),
#  (662,
#   'Luke Hampton',
#   'jillian50@gmail.com',
#   '1482 Richard Hill Suite 331\nNew John, PE Y1B9S1',
#   'Pattyshire',
#   'Northwest Territories',
#   'Jersey',
#   '551-315-8942 x698',
#   'Labore doloribus.',
#   '1964-09-19',
#   2126,
#   '2022-02-20 18:36:04.253622',
#   '2022-02-20 18:36:04.253623',
#   '183.9.68.89'),
#  (663,
#   'Brian Flores',
#   'wilsonmary@francis.com',
#   '95397 Nelson Orchard\nNorth Kristy, NT X2N 1P5',
#   'New Beckyberg',
#   'British Columbia',
#   'Papua New Guinea',
#   '685-795-0838 x943',
#   'Doloremque vero.',
#   '1976-11-24',
#   1645,
#   '2022-02-20 18:36:04.254923',
#   '2022-02-20 18:36:04.254924',
#   '198.103.236.150'),
#  (664,
#   'Robert Garcia',
#   'lewisthomas@yahoo.com',
#   '545 Rodriguez Mission\nLake Shellyborough, YT P9C2X5',
#   'Mitchellfort',
#   'Nova Scotia',
#   'San Marino',
#   '131-287-5578',
#   'Nostrum.',
#   '1947-05-30',
#   2069,
#   '2022-02-20 18:36:04.256067',
#   '2022-02-20 18:36:04.256069',
#   '213.162.3.19'),
#  (665,
#   'William Hickman',
#   'kreid@moss.com',
#   '165 Robert Ranch Suite 326\nWest Whitney, NB T7C 1K6',
#   'Edwintown',
#   'Manitoba',
#   'Thailand',
#   '541 547 8900',
#   'Saepe praesentium doloribus.',
#   '1933-01-17',
#   1777,
#   '2022-02-20 18:36:04.257190',
#   '2022-02-20 18:36:04.257191',
#   '174.159.31.11'),
#  (666,
#   'Charles Friedman',
#   'zperez@wang.com',
#   '22533 Todd Expressway\nNorth Catherine, ON V1R 2H7',
#   'South Brittanyberg',
#   'Ontario',
#   'Maldives',
#   '757.572.8905',
#   'Dolores quaerat provident.',
#   '1917-07-28',
#   1613,
#   '2022-02-20 18:36:04.258525',
#   '2022-02-20 18:36:04.258526',
#   '183.94.69.216'),
#  (667,
#   'Michelle Sharp',
#   'ldiaz@beard-miles.com',
#   '6594 Garrett Ridge\nTrevorfort, YT A1E6H3',
#   'South Jenniferhaven',
#   'Manitoba',
#   'Dominican Republic',
#   '192-730-7183',
#   'Accusamus eveniet.',
#   '1922-04-04',
#   1853,
#   '2022-02-20 18:36:04.259750',
#   '2022-02-20 18:36:04.259751',
#   '210.136.201.190'),
#  (668,
#   'Rachel Robles',
#   'ujoseph@gmail.com',
#   '06432 Ronald Summit Suite 802\nJohnmouth, QC L2M 4M9',
#   'Cannonville',
#   'New Brunswick',
#   'Sweden',
#   '+1 (885) 606-4459',
#   'Enim maiores natus.',
#   '1917-10-24',
#   1121,
#   '2022-02-20 18:36:04.260789',
#   '2022-02-20 18:36:04.260790',
#   '119.104.74.55'),
#  (669,
#   'Ryan Harrell',
#   'saraholloway@gmail.com',
#   '7501 Brown Plains\nSouth Pamela, NT K7B 7C1',
#   'Knightmouth',
#   'Prince Edward Island',
#   'Costa Rica',
#   '616 513 6224',
#   'Repellendus maiores.',
#   '2008-12-02',
#   2098,
#   '2022-02-20 18:36:04.262132',
#   '2022-02-20 18:36:04.262141',
#   '20.62.33.182'),
#  (670,
#   'Keith Rodriguez',
#   'maryjohnson@yahoo.com',
#   '921 Austin Islands\nGonzalezton, NS C4P 1G7',
#   'Taylormouth',
#   'Yukon Territory',
#   'Turkmenistan',
#   '+1 (177) 551-7307',
#   'Sed ipsam odit.',
#   '1971-02-28',
#   2201,
#   '2022-02-20 18:36:04.263236',
#   '2022-02-20 18:36:04.263237',
#   '190.72.1.184'),
#  (671,
#   'Scott Adkins',
#   'teresa72@thompson.net',
#   '390 Kenneth Island Apt. 162\nSouth Nicole, MB X4Y7L8',
#   'Jakefort',
#   'Northwest Territories',
#   'Japan',
#   '1-122-413-5844',
#   'Molestias sunt.',
#   '2006-06-30',
#   1221,
#   '2022-02-20 18:36:04.264232',
#   '2022-02-20 18:36:04.264234',
#   '173.200.163.71'),
#  (672,
#   'Kristine Hernandez',
#   'laura73@martinez.info',
#   '85471 Lee Locks Suite 816\nStaceyberg, NS P3J1T1',
#   'Stephanietown',
#   'Saskatchewan',
#   'Guinea',
#   '1 (865) 334-5344',
#   'Placeat voluptate.',
#   '1973-01-09',
#   1954,
#   '2022-02-20 18:36:04.265411',
#   '2022-02-20 18:36:04.265412',
#   '23.26.211.19'),
#  (673,
#   'Thomas Brown',
#   'martinezjason@hotmail.com',
#   '875 Sanchez Passage Suite 667\nGonzalezview, SK L4A4H9',
#   'Patrickborough',
#   'Ontario',
#   'Vanuatu',
#   '626 982 2100',
#   'Fuga reprehenderit.',
#   '1953-08-13',
#   2291,
#   '2022-02-20 18:36:04.266390',
#   '2022-02-20 18:36:04.266391',
#   '30.106.235.18'),
#  (674,
#   'Bryce Hoover',
#   'amymartinez@hotmail.com',
#   '2316 Kimberly Meadow\nJonstad, NS B4G 8K3',
#   'East Jeffrey',
#   'Newfoundland and Labrador',
#   'Kiribati',
#   '1-145-503-4434',
#   'Quos.',
#   '1914-09-04',
#   1302,
#   '2022-02-20 18:36:04.267292',
#   '2022-02-20 18:36:04.267294',
#   '162.19.171.19'),
#  (675,
#   'Shannon Morales',
#   'pamelashaffer@yahoo.com',
#   '78603 Caroline Courts Apt. 015\nPort Philip, ON S5A 2X3',
#   'Melaniemouth',
#   'Nunavut',
#   'Suriname',
#   '(549) 016-1665 x860',
#   'Quasi expedita.',
#   '2004-03-25',
#   1495,
#   '2022-02-20 18:36:04.268218',
#   '2022-02-20 18:36:04.268220',
#   '68.145.43.208'),
#  (676,
#   'Mikayla White',
#   'gabriela12@fuller.com',
#   '537 Roth Heights Suite 433\nNorth Russell, YT E2E4K1',
#   'Dawnhaven',
#   'Prince Edward Island',
#   'Benin',
#   '388-182-1146',
#   'Numquam tempora consequuntur.',
#   '2004-09-14',
#   2072,
#   '2022-02-20 18:36:04.270161',
#   '2022-02-20 18:36:04.270163',
#   '5.240.243.73'),
#  (677,
#   'Joe Martin',
#   'laurendavis@robertson.org',
#   '789 Troy Rapids\nWest Sherri, NT Y9A5C2',
#   'Port Tamarachester',
#   'Yukon Territory',
#   'Bahrain',
#   '771.596.1991',
#   'Atque dicta.',
#   '1985-10-14',
#   1920,
#   '2022-02-20 18:36:04.271931',
#   '2022-02-20 18:36:04.271933',
#   '69.99.8.206'),
#  (678,
#   'Kerry Jones',
#   'keith98@miller.biz',
#   '918 Nelson Estate Apt. 577\nLake Ericastad, ON M7J4X3',
#   'Lake Davidview',
#   'Yukon Territory',
#   'Bosnia and Herzegovina',
#   '420 434 5066',
#   'Amet provident.',
#   '2002-04-11',
#   2041,
#   '2022-02-20 18:36:04.273924',
#   '2022-02-20 18:36:04.273926',
#   '126.76.17.229'),
#  (679,
#   'Devin Mack',
#   'edwardstina@conway-farley.com',
#   '62638 Pena Shores\nEast Kelsey, ON E6K 3L9',
#   'Jaredstad',
#   'Nunavut',
#   'Finland',
#   '1-628-155-4634',
#   'Animi magnam delectus.',
#   '1963-07-15',
#   1247,
#   '2022-02-20 18:36:04.275406',
#   '2022-02-20 18:36:04.275407',
#   '107.221.253.146'),
#  (680,
#   'Andre Shannon',
#   'gavin29@wood.com',
#   '937 Nguyen Union Suite 906\nThompsonfort, NL K6S 1M4',
#   'Carlsonview',
#   'Alberta',
#   'New Zealand',
#   '+1 (886) 575-6380',
#   'Libero maiores non.',
#   '1974-03-24',
#   1031,
#   '2022-02-20 18:36:04.276525',
#   '2022-02-20 18:36:04.276527',
#   '212.212.27.233'),
#  (681,
#   'Leslie Peters',
#   'rogersbrandon@gmail.com',
#   '257 Dennis Isle Suite 460\nDarylport, NB C1Y3X3',
#   'Robinsonland',
#   'New Brunswick',
#   'Niue',
#   '+1 (930) 778-0298',
#   'Architecto veniam occaecati.',
#   '1938-08-15',
#   1012,
#   '2022-02-20 18:36:04.277486',
#   '2022-02-20 18:36:04.277487',
#   '87.102.238.229'),
#  (682,
#   'Elizabeth Jimenez',
#   'justin95@yahoo.com',
#   '72149 Jonathan Vista\nArmstrongton, PE C8L7X2',
#   'Grahammouth',
#   'British Columbia',
#   'Malaysia',
#   '697 696 3944',
#   'Dolorum perferendis saepe.',
#   '1916-06-24',
#   1117,
#   '2022-02-20 18:36:04.278353',
#   '2022-02-20 18:36:04.278354',
#   '63.195.80.170'),
#  (683,
#   'Richard Ryan',
#   'daniel28@yahoo.com',
#   '990 Pruitt Land\nPort Gina, NL X5V7E5',
#   'Thomasland',
#   'Nova Scotia',
#   'Serbia',
#   '(792) 285-2158',
#   'Recusandae vitae.',
#   '1993-07-28',
#   999,
#   '2022-02-20 18:36:04.279182',
#   '2022-02-20 18:36:04.279183',
#   '136.203.240.45'),
#  (684,
#   'Ian Brown',
#   'regina60@hotmail.com',
#   '14339 Thomas Gateway\nPort Meghan, NT E7M5X4',
#   'New Tiffanyview',
#   'British Columbia',
#   'Nauru',
#   '202 220 9500',
#   'Rem commodi.',
#   '2008-01-22',
#   1972,
#   '2022-02-20 18:36:04.280006',
#   '2022-02-20 18:36:04.280007',
#   '218.53.239.158'),
#  (685,
#   'Andrew Reyes',
#   'bmitchell@armstrong-hicks.com',
#   '8006 Sarah Ports Apt. 876\nBaldwinberg, NT H9G 3V3',
#   'New Edward',
#   'Ontario',
#   'Australia',
#   '+1 (134) 710-8891',
#   'Quod ipsum cupiditate.',
#   '1971-09-13',
#   1552,
#   '2022-02-20 18:36:04.281084',
#   '2022-02-20 18:36:04.281085',
#   '50.17.137.24'),
#  (686,
#   'Natalie Jordan',
#   'howardmartinez@yahoo.com',
#   '5832 Moore Key Suite 292\nNorth Tammystad, AB C1T 9E1',
#   'Glennmouth',
#   'Quebec',
#   'Morocco',
#   '(238) 623-3167 x134',
#   'Ex repudiandae vel.',
#   '1981-09-29',
#   2135,
#   '2022-02-20 18:36:04.282093',
#   '2022-02-20 18:36:04.282095',
#   '156.45.92.83'),
#  (687,
#   'Samantha Watkins',
#   'clarkkristina@yahoo.com',
#   '551 Cohen Inlet\nNew Kathleenmouth, ON E7R4T7',
#   'East Traci',
#   'Quebec',
#   'Niger',
#   '1-366-868-5829',
#   'Culpa voluptatum eveniet.',
#   '2017-06-12',
#   1599,
#   '2022-02-20 18:36:04.283003',
#   '2022-02-20 18:36:04.283005',
#   '78.148.149.33'),
#  (688,
#   'James Villa',
#   'stephanie72@carroll.info',
#   '955 Kari Square Suite 825\nPort Brianstad, MB K5E 9M9',
#   'Danielton',
#   'British Columbia',
#   'Holy See (Vatican City State)',
#   '924 007 8764',
#   'Eos molestiae reprehenderit.',
#   '1968-07-24',
#   1066,
#   '2022-02-20 18:36:04.283935',
#   '2022-02-20 18:36:04.283936',
#   '117.14.3.207'),
#  (689,
#   'Elizabeth West',
#   'robin17@gmail.com',
#   '621 Arthur Motorway\nSouth Traceyfort, SK L3B 5K9',
#   'South Debrafort',
#   'Manitoba',
#   'Congo',
#   '733 176 8672',
#   'Nisi culpa.',
#   '2012-08-05',
#   1259,
#   '2022-02-20 18:36:04.284738',
#   '2022-02-20 18:36:04.284739',
#   '223.250.61.54'),
#  (690,
#   'Rebecca Clark',
#   'cthomas@hotmail.com',
#   '85902 Miller Cliffs Apt. 311\nNew Lucasmouth, NS E4H 3T1',
#   'North Ianfort',
#   'Alberta',
#   'Puerto Rico',
#   '1-298-997-5032',
#   'Fugit numquam animi.',
#   '1919-04-25',
#   1556,
#   '2022-02-20 18:36:04.285616',
#   '2022-02-20 18:36:04.285617',
#   '108.104.74.158'),
#  (691,
#   'Juan Choi',
#   'moorestacey@yahoo.com',
#   '2444 Carter Haven\nEvansside, NB X2B 5M2',
#   'Paulburgh',
#   'Ontario',
#   'Jordan',
#   '393 699 5544',
#   'Ex saepe eligendi.',
#   '1940-02-05',
#   1628,
#   '2022-02-20 18:36:04.286539',
#   '2022-02-20 18:36:04.286540',
#   '211.103.18.88'),
#  (692,
#   'Rachel Davis',
#   'nathan27@gmail.com',
#   '12456 Mark Rapid Suite 404\nNew Bryanhaven, YT R8P 7L1',
#   'North Michelle',
#   'Saskatchewan',
#   'Belarus',
#   '161-684-1984 x774',
#   'Corrupti eos vero.',
#   '1952-04-15',
#   2240,
#   '2022-02-20 18:36:04.287365',
#   '2022-02-20 18:36:04.287367',
#   '118.141.44.84'),
#  (693,
#   'Dakota Payne',
#   'briddle@turner.info',
#   '084 Petty Drive\nNorth Carlshire, QC V5H 6C3',
#   'Ritterstad',
#   'New Brunswick',
#   'Liechtenstein',
#   '1 (620) 239-9065',
#   'Aut quia quasi.',
#   '2000-08-27',
#   1864,
#   '2022-02-20 18:36:04.288485',
#   '2022-02-20 18:36:04.288486',
#   '223.226.20.61'),
#  (694,
#   'Troy Rodriguez',
#   'ryanpamela@estes.biz',
#   '8048 Knight Neck Suite 540\nNew Lisa, NT N6R4J6',
#   'Lake Michael',
#   'Ontario',
#   'Mali',
#   '1-540-368-0051',
#   'Vel nisi nostrum.',
#   '1917-10-17',
#   1970,
#   '2022-02-20 18:36:04.289486',
#   '2022-02-20 18:36:04.289487',
#   '88.23.121.11'),
#  (695,
#   'Benjamin Garrison',
#   'emilysantos@stewart.biz',
#   '555 Martin Curve\nNew Joemouth, SK V6V 9A3',
#   'New Jefferyshire',
#   'Newfoundland and Labrador',
#   'Haiti',
#   '908-623-8186',
#   'Saepe ut quod.',
#   '1996-10-02',
#   1473,
#   '2022-02-20 18:36:04.290628',
#   '2022-02-20 18:36:04.290629',
#   '217.111.217.62'),
#  (696,
#   'Corey Norton',
#   'gregoryjames@hotmail.com',
#   '4978 Martinez Rapid Suite 245\nLake Kellyburgh, PE N3B3L6',
#   'West Davidton',
#   'Yukon Territory',
#   'Sweden',
#   '1-719-115-4819',
#   'Earum aspernatur.',
#   '1941-01-26',
#   2182,
#   '2022-02-20 18:36:04.291551',
#   '2022-02-20 18:36:04.291552',
#   '107.123.118.8'),
#  (697,
#   'Allen Grant',
#   'bailey29@yahoo.com',
#   '4569 Gregory Walks Apt. 757\nLeeborough, NT X8M 6B2',
#   'Jessicabury',
#   'Manitoba',
#   'Barbados',
#   '(826) 322-3008 x537',
#   'Ea veritatis.',
#   '1926-05-15',
#   1662,
#   '2022-02-20 18:36:04.292387',
#   '2022-02-20 18:36:04.292388',
#   '196.65.90.184'),
#  (698,
#   'Lisa Bradley',
#   'combskathleen@little-howard.org',
#   '68416 Bauer Turnpike Apt. 565\nNew Austin, PE K3G4K2',
#   'West Lisaberg',
#   'Yukon Territory',
#   'Spain',
#   '850-408-1381 x666',
#   'Deserunt consectetur cupiditate laborum.',
#   '1969-09-26',
#   1843,
#   '2022-02-20 18:36:04.293492',
#   '2022-02-20 18:36:04.293493',
#   '89.33.125.177'),
#  (699,
#   'Logan Arnold',
#   'james52@yahoo.com',
#   '154 Middleton Creek\nPort Krystal, QC H9J8L5',
#   'West Lauren',
#   'Manitoba',
#   'Marshall Islands',
#   '1-369-432-6148',
#   'Culpa.',
#   '1938-04-04',
#   2084,
#   '2022-02-20 18:36:04.294285',
#   '2022-02-20 18:36:04.294286',
#   '197.94.14.227'),
#  (700,
#   'Jessica Robles',
#   'dsmith@hotmail.com',
#   '8496 Michael Parks Suite 552\nLake Jason, ON K4C6M7',
#   'North Sandraberg',
#   'Northwest Territories',
#   'Indonesia',
#   '(837) 960-4987',
#   'Quae commodi.',
#   '1932-07-25',
#   1579,
#   '2022-02-20 18:36:04.295104',
#   '2022-02-20 18:36:04.295106',
#   '79.82.210.14'),
#  (701,
#   'Deborah Yoder',
#   'jfowler@williams-hansen.com',
#   '83441 Taylor Place Apt. 879\nBradleychester, ON P1G6L3',
#   'Alihaven',
#   'Ontario',
#   'Libyan Arab Jamahiriya',
#   '(440) 996-9921',
#   'Ab magnam.',
#   '2018-06-01',
#   1440,
#   '2022-02-20 18:36:04.296167',
#   '2022-02-20 18:36:04.296168',
#   '7.100.56.190'),
#  (702,
#   'Steven Atkinson',
#   'fmartinez@hotmail.com',
#   '95824 Michael Streets Apt. 317\nStaceyburgh, ON B3G1J5',
#   'North Markburgh',
#   'Alberta',
#   'Micronesia',
#   '(739) 318-2365 x969',
#   'Praesentium omnis.',
#   '1986-01-29',
#   1640,
#   '2022-02-20 18:36:04.297000',
#   '2022-02-20 18:36:04.297001',
#   '210.242.253.133'),
#  (703,
#   'Kelsey Henderson',
#   'jermainerose@hudson-myers.org',
#   '0942 Briana Plaza Apt. 476\nNorrisfurt, SK B5J9K8',
#   'Heatherburgh',
#   'Nova Scotia',
#   'Timor-Leste',
#   '+1 (537) 033-0020',
#   'Dolorem corrupti tenetur.',
#   '2017-03-20',
#   1430,
#   '2022-02-20 18:36:04.298084',
#   '2022-02-20 18:36:04.298086',
#   '56.47.210.1'),
#  (704,
#   'Katie Bell',
#   'rachael14@alvarado.com',
#   '93512 Jennifer Port Suite 067\nChavezfort, ON T9S3V9',
#   'Zhangton',
#   'Yukon Territory',
#   'Antigua and Barbuda',
#   '881-207-2503',
#   'Officiis incidunt suscipit.',
#   '1998-10-07',
#   1007,
#   '2022-02-20 18:36:04.299039',
#   '2022-02-20 18:36:04.299040',
#   '133.31.230.59'),
#  (705,
#   'Garrett Hill',
#   'smithdawn@yahoo.com',
#   '1947 Morris Trace\nAndrewfurt, NS P5P 4K3',
#   'Combsview',
#   'Ontario',
#   'Canada',
#   '105-533-6079',
#   'Dignissimos molestiae.',
#   '2009-12-01',
#   1592,
#   '2022-02-20 18:36:04.299963',
#   '2022-02-20 18:36:04.299964',
#   '92.246.168.125'),
#  (706,
#   'John Turner',
#   'hooverbrianna@gmail.com',
#   '08686 Silva Landing\nAlvarezville, MB J2B7R4',
#   'Frankview',
#   'Northwest Territories',
#   'United Arab Emirates',
#   '477-648-9193 x453',
#   'Earum.',
#   '1965-02-10',
#   2284,
#   '2022-02-20 18:36:04.300874',
#   '2022-02-20 18:36:04.300875',
#   '34.46.17.121'),
#  (707,
#   'Samantha Becker',
#   'montgomeryholly@morris.com',
#   '11080 Brenda Extensions Apt. 566\nHernandezmouth, MB B8B 4N6',
#   'Howardberg',
#   'Prince Edward Island',
#   'Tunisia',
#   '(651) 816-9983',
#   'Eaque eos nulla.',
#   '2015-11-30',
#   1057,
#   '2022-02-20 18:36:04.302085',
#   '2022-02-20 18:36:04.302086',
#   '184.174.216.95'),
#  (708,
#   'Theresa Joseph',
#   'bconway@baker-peters.net',
#   '8023 David Lane\nWilliamchester, AB R8M 8E2',
#   'Hullburgh',
#   'Ontario',
#   'Paraguay',
#   '857 400 1886',
#   'Exercitationem voluptas.',
#   '1919-06-15',
#   1799,
#   '2022-02-20 18:36:04.303589',
#   '2022-02-20 18:36:04.303590',
#   '111.117.41.11'),
#  (709,
#   'Jessica Phillips',
#   'danamartin@gmail.com',
#   '94221 Garza Keys Apt. 608\nBeverlytown, ON L8V2V1',
#   'West Cynthiatown',
#   'Northwest Territories',
#   'Peru',
#   '167.648.7542',
#   'Ipsum ab.',
#   '2013-12-11',
#   2413,
#   '2022-02-20 18:36:04.304914',
#   '2022-02-20 18:36:04.304916',
#   '92.106.108.242'),
#  (710,
#   'Nicholas Barber',
#   'bruce57@gmail.com',
#   '93750 Smith Brooks Apt. 176\nEast Wendy, QC B7S 5C6',
#   'Herreratown',
#   'Saskatchewan',
#   'Honduras',
#   '+1 (792) 672-9148',
#   'Officiis itaque ex.',
#   '1935-12-18',
#   1845,
#   '2022-02-20 18:36:04.306080',
#   '2022-02-20 18:36:04.306081',
#   '47.163.227.171'),
#  (711,
#   'Ricky Gould',
#   'benjaminmitchell@rodriguez.net',
#   '899 Alexander Freeway\nWest Scottburgh, NL R2R 3C3',
#   'Cisnerosville',
#   'Ontario',
#   'Belarus',
#   '+1 (643) 150-2168',
#   'Saepe saepe.',
#   '1931-08-08',
#   2254,
#   '2022-02-20 18:36:04.308187',
#   '2022-02-20 18:36:04.308190',
#   '214.218.3.195'),
#  (712,
#   'Tyler Pruitt',
#   'carpenterrobert@gonzalez.info',
#   '28084 James Bridge Suite 558\nEast Roger, QC N6M 1C9',
#   'East Justin',
#   'Alberta',
#   'Antarctica (the territory South of 60 deg S)',
#   '+1 (891) 029-9349',
#   'Totam laudantium.',
#   '2016-05-19',
#   1400,
#   '2022-02-20 18:36:04.310282',
#   '2022-02-20 18:36:04.310285',
#   '96.117.130.43'),
#  (713,
#   'Connie Davis',
#   'theresamassey@mitchell.org',
#   '029 Phillips Rue\nAmybury, NU Y4T7H7',
#   'South Linda',
#   'British Columbia',
#   'Wallis and Futuna',
#   '255.430.6636',
#   'Quia quaerat neque.',
#   '1961-05-14',
#   2097,
#   '2022-02-20 18:36:04.312691',
#   '2022-02-20 18:36:04.312693',
#   '157.53.170.23'),
#  (714,
#   'Diana Williams',
#   'valdezkeith@yahoo.com',
#   '4821 Moore Overpass Suite 872\nWest Nathanburgh, NL J2Y4L8',
#   'Allentown',
#   'Prince Edward Island',
#   'British Indian Ocean Territory (Chagos Archipelago)',
#   '1 (202) 786-0032',
#   'Optio magni neque.',
#   '1951-05-25',
#   1892,
#   '2022-02-20 18:36:04.315505',
#   '2022-02-20 18:36:04.315508',
#   '213.169.212.20'),
#  (715,
#   'Richard Anderson',
#   'kbuckley@perez.com',
#   '950 Micheal Orchard\nStokeschester, BC R9C 4P3',
#   'East Leon',
#   'Nova Scotia',
#   'Uruguay',
#   '(208) 000-8279 x244',
#   'Molestiae molestiae.',
#   '1923-08-09',
#   1812,
#   '2022-02-20 18:36:04.317160',
#   '2022-02-20 18:36:04.317161',
#   '181.2.138.252'),
#  (716,
#   'Karen Roberts',
#   'andrewjohnson@townsend.org',
#   '2803 Werner Squares Apt. 854\nPort Timothy, BC R5C8C8',
#   'Andradebury',
#   'Manitoba',
#   'Tokelau',
#   '1-740-373-3801',
#   'Sit ea est.',
#   '2010-07-08',
#   2485,
#   '2022-02-20 18:36:04.319042',
#   '2022-02-20 18:36:04.319045',
#   '113.34.38.231'),
#  (717,
#   'Justin Smith',
#   'nwaller@gmail.com',
#   '71611 Elizabeth Estate Apt. 688\nMyersstad, PE B4C 9Y2',
#   'Jamesmouth',
#   'Prince Edward Island',
#   'Australia',
#   '(278) 693-6154',
#   'Maiores.',
#   '2013-08-29',
#   1300,
#   '2022-02-20 18:36:04.320216',
#   '2022-02-20 18:36:04.320217',
#   '61.13.31.39'),
#  (718,
#   'Christian Rojas',
#   'anthony63@gmail.com',
#   '24238 Walter Camp\nSouth Jasontown, ON H7V5K5',
#   'East Donnaberg',
#   'Quebec',
#   'Syrian Arab Republic',
#   '482-421-2970',
#   'Neque architecto.',
#   '1996-01-31',
#   2188,
#   '2022-02-20 18:36:04.321088',
#   '2022-02-20 18:36:04.321089',
#   '174.238.17.45'),
#  (719,
#   'Nicholas Burgess',
#   'stephanie23@yahoo.com',
#   '2956 Lopez Harbor\nNorth Matthewburgh, YT R4E9X3',
#   'Johnmouth',
#   'New Brunswick',
#   'Bouvet Island (Bouvetoya)',
#   '1-598-417-3419',
#   'Quaerat deleniti explicabo.',
#   '1945-07-12',
#   1810,
#   '2022-02-20 18:36:04.322288',
#   '2022-02-20 18:36:04.322289',
#   '91.194.219.234'),
#  (720,
#   'Laura Schmidt',
#   'riveraryan@yahoo.com',
#   '928 Alan Lock Suite 046\nTroymouth, YT R3S 6N2',
#   'New Ericatown',
#   'Ontario',
#   'Turkmenistan',
#   '925-205-4369 x784',
#   'Veniam.',
#   '1949-06-26',
#   1049,
#   '2022-02-20 18:36:04.323344',
#   '2022-02-20 18:36:04.323346',
#   '200.171.16.241'),
#  (721,
#   'Tyler Lewis',
#   'jenniferperez@gmail.com',
#   '97324 Jesse Burg\nNancyland, NT T8R 1E7',
#   'New Ann',
#   'Newfoundland and Labrador',
#   'Israel',
#   '(830) 539-3571',
#   'Quisquam repellendus.',
#   '1955-02-21',
#   1322,
#   '2022-02-20 18:36:04.324281',
#   '2022-02-20 18:36:04.324283',
#   '218.251.62.138'),
#  (722,
#   'Marvin Newton',
#   'patrickdavis@hotmail.com',
#   '4612 Amanda Shoal\nRobertfort, NS Y3E 1H8',
#   'Murphymouth',
#   'New Brunswick',
#   'Micronesia',
#   '168 268 7662',
#   'Asperiores dolores ullam.',
#   '2002-05-20',
#   1203,
#   '2022-02-20 18:36:04.325216',
#   '2022-02-20 18:36:04.325217',
#   '132.1.221.232'),
#  (723,
#   'Sean Harmon',
#   'jamesthomas@gmail.com',
#   '00360 Christopher Stream\nEast Tamaraview, SK J2T2J5',
#   'South Jeanette',
#   'Northwest Territories',
#   'Wallis and Futuna',
#   '829 204 0090',
#   'Recusandae esse.',
#   '2007-03-08',
#   1547,
#   '2022-02-20 18:36:04.326126',
#   '2022-02-20 18:36:04.326128',
#   '44.172.98.35'),
#  (724,
#   'Noah Woods',
#   'zharrington@weiss.biz',
#   '63543 Brown Ports Apt. 328\nSouth Maryberg, BC H7R 6A7',
#   'North Allen',
#   'Prince Edward Island',
#   'Sudan',
#   '1-941-341-5559',
#   'Saepe quaerat.',
#   '2005-12-20',
#   1052,
#   '2022-02-20 18:36:04.327303',
#   '2022-02-20 18:36:04.327305',
#   '137.11.125.164'),
#  (725,
#   'Juan Davis',
#   'alex06@hotmail.com',
#   '972 Morgan Mountains\nWest Robert, NS C6A 7Y4',
#   'Lake Anna',
#   'Nova Scotia',
#   'Sierra Leone',
#   '611.802.1791',
#   'Quod ea.',
#   '2017-06-24',
#   2264,
#   '2022-02-20 18:36:04.328094',
#   '2022-02-20 18:36:04.328095',
#   '107.108.201.2'),
#  (726,
#   'Richard Krueger',
#   'shane61@hotmail.com',
#   '37865 Brooks Unions Suite 047\nJohnbury, BC P4A9P4',
#   'Rebeccahaven',
#   'Northwest Territories',
#   'Taiwan',
#   '801-624-3560 x588',
#   'Ex delectus alias.',
#   '1996-07-08',
#   1352,
#   '2022-02-20 18:36:04.328968',
#   '2022-02-20 18:36:04.328969',
#   '155.212.220.241'),
#  (727,
#   'Jose Banks',
#   'paulsimmons@martin-taylor.com',
#   '53809 Barbara Estates Suite 437\nRamirezside, YT G3Y1K5',
#   'West Valerie',
#   'Northwest Territories',
#   'San Marino',
#   '+1 (205) 515-1756',
#   'Ex.',
#   '1952-08-23',
#   1907,
#   '2022-02-20 18:36:04.330914',
#   '2022-02-20 18:36:04.330916',
#   '89.57.41.72'),
#  (728,
#   'Nicole Gonzalez',
#   'beckyballard@curry.com',
#   '851 Lindsey Vista\nPort Danielle, NS T4B 4S8',
#   'West Walterland',
#   'Saskatchewan',
#   'Iraq',
#   '498-525-8382',
#   'Occaecati praesentium reprehenderit.',
#   '1941-08-26',
#   1345,
#   '2022-02-20 18:36:04.332222',
#   '2022-02-20 18:36:04.332223',
#   '103.172.132.135'),
#  (729,
#   'Michael Blair',
#   'masonbill@hotmail.com',
#   '903 Merritt Rapid\nNorth Troy, MB L2R2S9',
#   'New Elizabethport',
#   'Quebec',
#   'Guinea',
#   '(257) 148-4688',
#   'Optio labore.',
#   '1978-03-06',
#   1232,
#   '2022-02-20 18:36:04.333227',
#   '2022-02-20 18:36:04.333228',
#   '56.210.233.46'),
#  (730,
#   'Paul Harris',
#   'lorettathomas@hotmail.com',
#   '5102 Briana Rapids Suite 755\nLake Stevenmouth, BC Y2G6R1',
#   'South Joshuahaven',
#   'Alberta',
#   'Bolivia',
#   '(463) 018-5947',
#   'Harum consequuntur.',
#   '1984-07-24',
#   1103,
#   '2022-02-20 18:36:04.334186',
#   '2022-02-20 18:36:04.334187',
#   '33.242.174.255'),
#  (731,
#   'Joshua Webster',
#   'margaretellis@yahoo.com',
#   '8494 Garcia Motorway\nPort Lisatown, AB K3T2E1',
#   'Jonesland',
#   'Quebec',
#   'Mauritania',
#   '(504) 682-5794',
#   'Perspiciatis.',
#   '2001-01-23',
#   1373,
#   '2022-02-20 18:36:04.335163',
#   '2022-02-20 18:36:04.335164',
#   '105.121.219.149'),
#  (732,
#   'Paul Osborne',
#   'jball@yahoo.com',
#   '82218 Smith Motorway Suite 186\nColeberg, PE H9R8X3',
#   'South Melvin',
#   'Quebec',
#   'Paraguay',
#   '1-510-054-6534',
#   'Tempore saepe.',
#   '1912-12-26',
#   2329,
#   '2022-02-20 18:36:04.336042',
#   '2022-02-20 18:36:04.336043',
#   '76.191.50.165'),
#  (733,
#   'Debra Mueller',
#   'mitchellchristian@hendricks-dean.com',
#   '96177 Kimberly Village Apt. 806\nSouth Briannastad, MB V3B7J5',
#   'Mendozahaven',
#   'Newfoundland and Labrador',
#   'Micronesia',
#   '167-970-0705 x758',
#   'Nostrum.',
#   '1979-02-09',
#   1243,
#   '2022-02-20 18:36:04.337190',
#   '2022-02-20 18:36:04.337191',
#   '194.21.154.138'),
#  (734,
#   'Shawn James',
#   'jamesking@waters.com',
#   '98583 Moody Valley\nPatelmouth, QC T7R 2B4',
#   'East Paulfurt',
#   'Nova Scotia',
#   'Montserrat',
#   '185 541 7170',
#   'Sunt nulla quaerat.',
#   '1967-07-10',
#   1973,
#   '2022-02-20 18:36:04.338390',
#   '2022-02-20 18:36:04.338391',
#   '207.148.150.254'),
#  (735,
#   'Blake Bentley',
#   'jeremyholloway@hotmail.com',
#   '54754 Daniel Fields Suite 778\nBrownfurt, NU Y4Y 5P6',
#   'Alyssastad',
#   'Yukon Territory',
#   'Ethiopia',
#   '1 (669) 899-8548',
#   'Voluptate sed accusantium.',
#   '1975-08-06',
#   1914,
#   '2022-02-20 18:36:04.339328',
#   '2022-02-20 18:36:04.339329',
#   '62.175.7.161'),
#  (736,
#   'Travis Bates',
#   'cindystone@hernandez.org',
#   '29500 Lozano Lock\nNorth Sarastad, NS N3M3E6',
#   'Olsonberg',
#   'New Brunswick',
#   'United States Virgin Islands',
#   '1 (565) 296-2083',
#   'Velit facilis maxime.',
#   '1992-10-07',
#   2451,
#   '2022-02-20 18:36:04.340359',
#   '2022-02-20 18:36:04.340361',
#   '27.90.144.180'),
#  (737,
#   'Paul Osborne',
#   'nkoch@gmail.com',
#   '9449 Karen Square Apt. 442\nNew Paul, NL R2G5K8',
#   'Lake Daniellehaven',
#   'Newfoundland and Labrador',
#   'El Salvador',
#   '980.583.7873',
#   'Praesentium officiis.',
#   '1940-03-24',
#   2390,
#   '2022-02-20 18:36:04.341180',
#   '2022-02-20 18:36:04.341182',
#   '152.221.43.52'),
#  (738,
#   'Jose Carter',
#   'audreyhenry@yahoo.com',
#   '853 Zimmerman Unions Suite 246\nSouth Scott, SK P9C6K9',
#   'North Amanda',
#   'Newfoundland and Labrador',
#   'Isle of Man',
#   '694.352.7029',
#   'Expedita ducimus perspiciatis.',
#   '1943-10-05',
#   1846,
#   '2022-02-20 18:36:04.342125',
#   '2022-02-20 18:36:04.342126',
#   '32.250.198.89'),
#  (739,
#   'Michael Ward',
#   'jonesjohnny@yahoo.com',
#   '15462 Troy Bypass Suite 986\nBerryfurt, PE R1J2V6',
#   'Nicholsberg',
#   'Nova Scotia',
#   'Wallis and Futuna',
#   '571-855-5180 x082',
#   'Exercitationem quam accusamus.',
#   '1953-06-28',
#   2486,
#   '2022-02-20 18:36:04.343059',
#   '2022-02-20 18:36:04.343060',
#   '172.111.197.60'),
#  (740,
#   'Felicia Mcdonald',
#   'wmurray@smith.biz',
#   '5228 Myers Cliffs\nNew Kristen, PE A3H2K2',
#   'Singletonfurt',
#   'Quebec',
#   'Gambia',
#   '688-361-1694',
#   'Natus fugit quidem.',
#   '1909-10-29',
#   1328,
#   '2022-02-20 18:36:04.344195',
#   '2022-02-20 18:36:04.344196',
#   '195.152.228.190'),
#  (741,
#   'Tara Carey',
#   'youngcynthia@gmail.com',
#   '364 Smith Cliff Suite 205\nWest Melissatown, NL R6Y 1H7',
#   'East Whitney',
#   'Newfoundland and Labrador',
#   'Aruba',
#   '264-501-5898 x510',
#   'Veniam consectetur.',
#   '1914-07-10',
#   2039,
#   '2022-02-20 18:36:04.345150',
#   '2022-02-20 18:36:04.345151',
#   '158.206.81.255'),
#  (742,
#   'Erika Miller',
#   'john60@carlson.com',
#   '3110 Schultz Row Suite 979\nCoryside, MB R1S4H4',
#   'South Robert',
#   'British Columbia',
#   'United Arab Emirates',
#   '+1 (518) 147-4046',
#   'Cumque cumque.',
#   '2003-06-18',
#   1565,
#   '2022-02-20 18:36:04.346430',
#   '2022-02-20 18:36:04.346431',
#   '149.0.196.201'),
#  (743,
#   'Anita Hamilton',
#   'jason52@flores.com',
#   '3463 Kathy Plain\nPort Jodishire, BC B4N8P5',
#   'Staffordmouth',
#   'Quebec',
#   'Armenia',
#   '(312) 832-6852',
#   'Laudantium.',
#   '2012-02-04',
#   2200,
#   '2022-02-20 18:36:04.347629',
#   '2022-02-20 18:36:04.347630',
#   '55.235.41.174'),
#  (744,
#   'Timothy Contreras',
#   'ekelly@hotmail.com',
#   '5166 Scott Forge\nLake Diane, QC C7T 7K1',
#   'Tracystad',
#   'Northwest Territories',
#   'Guernsey',
#   '+1 (886) 171-9027',
#   'Nam expedita at.',
#   '2018-05-12',
#   1634,
#   '2022-02-20 18:36:04.348464',
#   '2022-02-20 18:36:04.348465',
#   '88.85.157.166'),
#  (745,
#   'Mary Holmes',
#   'iwilson@yahoo.com',
#   '911 Tiffany Isle Suite 657\nMaryhaven, MB J6X 7T9',
#   'New Sarah',
#   'Nunavut',
#   'Gambia',
#   '(964) 595-6447 x560',
#   'Nulla delectus reprehenderit harum.',
#   '1919-03-10',
#   2476,
#   '2022-02-20 18:36:04.349299',
#   '2022-02-20 18:36:04.349302',
#   '194.105.16.71'),
#  (746,
#   'Steven Craig',
#   'leonardcraig@robinson-morales.net',
#   '03846 Jessica Squares\nShelbychester, NL M6J9Y6',
#   'Abigailfurt',
#   'Northwest Territories',
#   'Tuvalu',
#   '375-315-8071',
#   'Voluptas quam.',
#   '1929-08-19',
#   1994,
#   '2022-02-20 18:36:04.350407',
#   '2022-02-20 18:36:04.350408',
#   '8.76.114.49'),
#  (747,
#   'Denise Martin',
#   'bsmith@yahoo.com',
#   '375 Brady Meadow\nJackieburgh, NT B3H2Y8',
#   'Lewismouth',
#   'Quebec',
#   'Italy',
#   '253.594.4063',
#   'In totam.',
#   '2011-10-18',
#   1234,
#   '2022-02-20 18:36:04.351256',
#   '2022-02-20 18:36:04.351271',
#   '86.245.204.0'),
#  (748,
#   'Kimberly Mathews',
#   'monicawebster@yahoo.com',
#   '2650 Christopher Islands\nSusanhaven, SK B9A 9G8',
#   'Weavermouth',
#   'Alberta',
#   "Lao People's Democratic Republic",
#   '593-679-0773 x443',
#   'Omnis mollitia iure.',
#   '1922-12-03',
#   2467,
#   '2022-02-20 18:36:04.352172',
#   '2022-02-20 18:36:04.352173',
#   '112.23.100.233'),
#  (749,
#   'Martin Leon',
#   'ubennett@steele-kim.com',
#   '187 Patricia Street\nMelissachester, SK G6T2A3',
#   'Lake Holly',
#   'Ontario',
#   'Lesotho',
#   '1 (436) 662-8591',
#   'Ea.',
#   '1963-03-16',
#   2023,
#   '2022-02-20 18:36:04.353159',
#   '2022-02-20 18:36:04.353160',
#   '193.214.107.82'),
#  (750,
#   'Dawn Young',
#   'jjohnson@hotmail.com',
#   '1828 Hannah Mount\nJacquelineburgh, BC K5L 2E2',
#   'Burtonhaven',
#   'Newfoundland and Labrador',
#   'Dominican Republic',
#   '1 (877) 897-8863',
#   'Accusamus nostrum eius amet.',
#   '1991-05-20',
#   1460,
#   '2022-02-20 18:36:04.354000',
#   '2022-02-20 18:36:04.354001',
#   '139.17.181.80'),
#  (751,
#   'Patrick Wilson',
#   'sarah11@yahoo.com',
#   '8346 Rhonda Gateway Apt. 730\nEast Gwendolyn, QC P9S7B3',
#   'Wongmouth',
#   'Yukon Territory',
#   'Slovenia',
#   '+1 (624) 885-2864',
#   'Molestias.',
#   '1967-05-18',
#   1579,
#   '2022-02-20 18:36:04.354834',
#   '2022-02-20 18:36:04.354835',
#   '163.11.121.94'),
#  (752,
#   'Daniel Fletcher',
#   'mcclurelisa@reese.com',
#   '385 James Flats Apt. 738\nJohnview, SK G3B8G1',
#   'East Gregory',
#   'Nunavut',
#   'Timor-Leste',
#   '1-281-868-4729',
#   'Dolorum voluptatibus.',
#   '1961-10-27',
#   2441,
#   '2022-02-20 18:36:04.355812',
#   '2022-02-20 18:36:04.355814',
#   '195.14.218.3'),
#  (753,
#   'Paula Jones',
#   'gtorres@hotmail.com',
#   '896 Perez Cove Apt. 754\nLake Jorgeton, MB B8T3A7',
#   'Port Kristinafort',
#   'British Columbia',
#   'Puerto Rico',
#   '(131) 190-2729 x010',
#   'Eius facere exercitationem nihil.',
#   '1984-11-19',
#   1267,
#   '2022-02-20 18:36:04.356934',
#   '2022-02-20 18:36:04.356939',
#   '34.83.97.94'),
#  (754,
#   'Michael Owen',
#   'udavis@gmail.com',
#   '7485 Douglas Village Suite 176\nPort Daniel, BC M3H5J4',
#   'East Eric',
#   'British Columbia',
#   'Guinea',
#   '1 (796) 310-7962',
#   'Et.',
#   '2015-08-25',
#   1560,
#   '2022-02-20 18:36:04.357939',
#   '2022-02-20 18:36:04.357940',
#   '119.26.125.141'),
#  (755,
#   'Jerry Ramirez',
#   'harmonamy@gmail.com',
#   '35197 Jessica Orchard Apt. 876\nCisnerosbury, MB Y9S4Y2',
#   'South Alexborough',
#   'Ontario',
#   'Malaysia',
#   '1-115-157-2867',
#   'Assumenda sit.',
#   '1922-04-19',
#   1120,
#   '2022-02-20 18:36:04.359000',
#   '2022-02-20 18:36:04.359002',
#   '196.244.241.28'),
#  (756,
#   'Christian Price',
#   'crystal33@rangel-sanchez.com',
#   '18590 Kayla Points Suite 448\nSandystad, NS L8H5K2',
#   'Lake Charlesside',
#   'Saskatchewan',
#   'Switzerland',
#   '(155) 674-1445 x784',
#   'Eos iste.',
#   '1950-01-25',
#   1451,
#   '2022-02-20 18:36:04.360081',
#   '2022-02-20 18:36:04.360082',
#   '89.165.149.247'),
#  (757,
#   'Thomas Meyer',
#   'dharper@suarez.com',
#   '83207 Grimes Wells\nHamiltonchester, BC B8S5R6',
#   'Griffinfort',
#   'Prince Edward Island',
#   'Qatar',
#   '(507) 447-1883 x586',
#   'Alias explicabo.',
#   '1913-07-13',
#   1936,
#   '2022-02-20 18:36:04.361281',
#   '2022-02-20 18:36:04.361283',
#   '159.216.174.237'),
#  (758,
#   'Colleen Thomas',
#   'crystalmejia@mclean.com',
#   '243 David Walk\nBenjaminview, NL E9G 5K1',
#   'Nielsenview',
#   'New Brunswick',
#   'Palau',
#   '(629) 825-0146',
#   'Aperiam numquam laborum quasi.',
#   '1960-03-06',
#   1151,
#   '2022-02-20 18:36:04.362381',
#   '2022-02-20 18:36:04.362382',
#   '156.70.119.210'),
#  (759,
#   'Daniel Murphy',
#   'tparks@yahoo.com',
#   '813 Todd Valley Suite 127\nWilliamsonville, SK A4N2E6',
#   'Georgefort',
#   'Nunavut',
#   'Guatemala',
#   '(425) 120-0700 x305',
#   'Maxime.',
#   '1989-05-23',
#   2216,
#   '2022-02-20 18:36:04.363279',
#   '2022-02-20 18:36:04.363280',
#   '36.52.204.234'),
#  (760,
#   'Martha Oconnor',
#   'jacksonsamantha@gmail.com',
#   '011 Marissa Throughway\nSouth Marvin, MB N3L2A9',
#   'Alvarezhaven',
#   'New Brunswick',
#   'Maldives',
#   '255.917.1496',
#   'Blanditiis vitae ipsa.',
#   '1989-12-04',
#   1464,
#   '2022-02-20 18:36:04.364172',
#   '2022-02-20 18:36:04.364174',
#   '7.178.102.46'),
#  (761,
#   'Rebecca Owen',
#   'nancysilva@hotmail.com',
#   '31227 Sandra Union\nEast Erin, QC X2S 3Y2',
#   'West Craig',
#   'Saskatchewan',
#   'Gabon',
#   '(276) 424-1181',
#   'Dolor vero.',
#   '1977-03-09',
#   2459,
#   '2022-02-20 18:36:04.365078',
#   '2022-02-20 18:36:04.365079',
#   '171.227.44.242'),
#  (762,
#   'Kara Aguilar',
#   'lhatfield@harmon-sanchez.info',
#   '94287 Woods Port Apt. 120\nNorth Philip, MB L8X2M6',
#   'Richardsonfurt',
#   'British Columbia',
#   'Mali',
#   '966-087-7374',
#   'Sapiente provident beatae.',
#   '2018-08-01',
#   2226,
#   '2022-02-20 18:36:04.366163',
#   '2022-02-20 18:36:04.366164',
#   '146.42.198.126'),
#  (763,
#   'Patrick Moyer',
#   'boothannette@gmail.com',
#   '330 Adams Cliffs\nAndreside, NB K9R6R1',
#   'Williamsfurt',
#   'Prince Edward Island',
#   'Northern Mariana Islands',
#   '1 (221) 606-0997',
#   'Ad accusantium quis.',
#   '1955-04-07',
#   1924,
#   '2022-02-20 18:36:04.367101',
#   '2022-02-20 18:36:04.367102',
#   '164.218.82.124'),
#  (764,
#   'Emily Patterson',
#   'michael07@matthews.biz',
#   '323 Ayers Centers Suite 790\nLake Ernestville, NU M8C 3L7',
#   'West Earl',
#   'Newfoundland and Labrador',
#   'Papua New Guinea',
#   '333-546-1821',
#   'Nam veniam accusantium.',
#   '1952-06-22',
#   1602,
#   '2022-02-20 18:36:04.368044',
#   '2022-02-20 18:36:04.368045',
#   '154.4.33.52'),
#  (765,
#   'Daniel Hodges',
#   'mooreamanda@benson.info',
#   '59119 Solis Mount\nSouth Micheal, QC G9H 6L3',
#   'Leonardville',
#   'Alberta',
#   'Bosnia and Herzegovina',
#   '(253) 168-9408 x170',
#   'Eum illum.',
#   '1910-12-23',
#   2140,
#   '2022-02-20 18:36:04.369217',
#   '2022-02-20 18:36:04.369219',
#   '113.223.143.164'),
#  (766,
#   'Brianna English',
#   'jeff68@webb-li.info',
#   '7170 Joanna Station\nLake Amandatown, YT K6R6V7',
#   'Jenniferchester',
#   'Alberta',
#   'Latvia',
#   '1-842-281-9109',
#   'Nisi nemo accusantium.',
#   '1922-12-18',
#   1148,
#   '2022-02-20 18:36:04.370587',
#   '2022-02-20 18:36:04.370588',
#   '9.199.187.43'),
#  (767,
#   'Tara Bradford MD',
#   'danielle40@hotmail.com',
#   '569 Peter Drives\nCarolinehaven, NL L6J 8X6',
#   'North Nicoleton',
#   'Prince Edward Island',
#   'Jersey',
#   '772.713.9172',
#   'Nobis dolor.',
#   '1991-07-20',
#   1166,
#   '2022-02-20 18:36:04.371496',
#   '2022-02-20 18:36:04.371497',
#   '80.77.161.106'),
#  (768,
#   'Brittany Yu',
#   'elainebrown@yahoo.com',
#   '27176 Hicks Branch\nLyonshaven, ON L4A1B7',
#   'New Matthew',
#   'Saskatchewan',
#   'Djibouti',
#   '709.728.0547',
#   'Natus tenetur nesciunt.',
#   '1924-03-30',
#   2239,
#   '2022-02-20 18:36:04.372467',
#   '2022-02-20 18:36:04.372469',
#   '161.22.229.20'),
#  (769,
#   'Susan Alvarez',
#   'crystal28@williams.com',
#   '04110 Amy Garden Suite 317\nWest Ericmouth, AB H3C 6K4',
#   'Port Billyshire',
#   'Manitoba',
#   'Madagascar',
#   '575-773-9177',
#   'Iste rerum mollitia.',
#   '1957-08-02',
#   1079,
#   '2022-02-20 18:36:04.373442',
#   '2022-02-20 18:36:04.373443',
#   '212.29.181.25'),
#  (770,
#   'Chad Leonard',
#   'morrissherri@ewing.net',
#   '511 Christine Centers Apt. 586\nJasonland, ON J2N 1A9',
#   'Lake Monique',
#   'Nunavut',
#   'Bolivia',
#   '423-883-5125 x008',
#   'Voluptates qui.',
#   '1966-03-25',
#   1618,
#   '2022-02-20 18:36:04.374634',
#   '2022-02-20 18:36:04.374635',
#   '220.168.98.211'),
#  (771,
#   'Devon Wang',
#   'rebecca21@weaver.com',
#   '038 Johnson Pass\nSouth Crystal, BC S4V 6L2',
#   'New James',
#   'British Columbia',
#   'Bosnia and Herzegovina',
#   '316.938.1789',
#   'Accusamus blanditiis.',
#   '1972-12-05',
#   1373,
#   '2022-02-20 18:36:04.375574',
#   '2022-02-20 18:36:04.375575',
#   '21.139.6.21'),
#  (772,
#   'Anna Blair',
#   'randallgalvan@miller.com',
#   '95370 Johnson Ports Apt. 850\nMolinaside, BC J9T 3B9',
#   'Bradleybury',
#   'Ontario',
#   'Argentina',
#   '+1 (128) 815-4123',
#   'Occaecati ipsam neque.',
#   '1991-10-06',
#   2358,
#   '2022-02-20 18:36:04.377243',
#   '2022-02-20 18:36:04.377244',
#   '72.231.138.190'),
#  (773,
#   'Shannon Griffin',
#   'diazdesiree@gmail.com',
#   '772 Kathy Estate Suite 154\nGonzalezmouth, QC A9X5T4',
#   'New Grantmouth',
#   'British Columbia',
#   'Gibraltar',
#   '+1 (317) 688-6831',
#   'Earum minima sint.',
#   '1932-05-10',
#   2244,
#   '2022-02-20 18:36:04.378333',
#   '2022-02-20 18:36:04.378334',
#   '77.171.32.123'),
#  (774,
#   'Larry Baker',
#   'sthornton@levine.com',
#   '26032 Elizabeth Springs\nMichelleberg, NS Y4T 6X1',
#   'Rachelhaven',
#   'Ontario',
#   'Cyprus',
#   '1-521-539-5606',
#   'Omnis distinctio.',
#   '1909-04-06',
#   1274,
#   '2022-02-20 18:36:04.379411',
#   '2022-02-20 18:36:04.379413',
#   '197.115.74.13'),
#  (775,
#   'Daniel Holland',
#   'lcarlson@murphy.com',
#   '175 Justin Villages Apt. 455\nTuckerfurt, MB S8E6A8',
#   'Port Ralphberg',
#   'Saskatchewan',
#   'Estonia',
#   '234.162.5006',
#   'Ratione doloremque.',
#   '1975-08-16',
#   2208,
#   '2022-02-20 18:36:04.380630',
#   '2022-02-20 18:36:04.380631',
#   '29.66.85.36'),
#  (776,
#   'Marcus Gilbert',
#   'jeffrey67@simon.com',
#   '411 Mark Corners\nGarciaton, PE R9B3A5',
#   'Robersonshire',
#   'Northwest Territories',
#   'Guinea-Bissau',
#   '+1 (680) 447-8791',
#   'Aperiam iste et.',
#   '1982-07-08',
#   1018,
#   '2022-02-20 18:36:04.381748',
#   '2022-02-20 18:36:04.381749',
#   '184.89.6.79'),
#  (777,
#   'Ashley Porter',
#   'jonathanphillips@gmail.com',
#   '9471 Manning Path\nNew Jose, YT V7L 9N8',
#   'New Brian',
#   'Northwest Territories',
#   'Italy',
#   '585-261-9717',
#   'Voluptates perferendis.',
#   '1928-06-22',
#   2127,
#   '2022-02-20 18:36:04.382721',
#   '2022-02-20 18:36:04.382722',
#   '70.206.120.243'),
#  (778,
#   'James Porter',
#   'mackenzie38@johnson-walker.biz',
#   '790 William Creek Suite 615\nLake Dan, NL J5Y 1B5',
#   'Lake Cameronland',
#   'Manitoba',
#   'Uzbekistan',
#   '(624) 822-8300',
#   'Quo perspiciatis aperiam.',
#   '1911-08-09',
#   1399,
#   '2022-02-20 18:36:04.383742',
#   '2022-02-20 18:36:04.383744',
#   '9.208.187.63'),
#  (779,
#   'Dr. Peter Nguyen',
#   'maygeorge@yahoo.com',
#   '1824 Rodriguez Drives\nJenningsmouth, ON K8S 6X4',
#   'West Nicolasburgh',
#   'Prince Edward Island',
#   'Panama',
#   '1-358-844-6856',
#   'Sapiente natus quasi.',
#   '2009-12-25',
#   2333,
#   '2022-02-20 18:36:04.384716',
#   '2022-02-20 18:36:04.384717',
#   '145.112.96.204'),
#  (780,
#   'Jacob Summers',
#   'gregory61@francis-jackson.org',
#   '305 Moon Key\nPaulland, NB P8N 9B7',
#   'Mccannbury',
#   'Nunavut',
#   'Algeria',
#   '997-826-4826',
#   'Perferendis atque delectus dolore.',
#   '1919-01-11',
#   1141,
#   '2022-02-20 18:36:04.385732',
#   '2022-02-20 18:36:04.385733',
#   '158.139.21.179'),
#  (781,
#   'Audrey Hawkins',
#   'greenscott@ross-mcintyre.org',
#   '55093 Hodge Well Apt. 621\nPort Andrewside, NS P1H3G7',
#   'Manningland',
#   'Quebec',
#   'Comoros',
#   '188.945.9558',
#   'Voluptates odio.',
#   '1931-05-03',
#   1108,
#   '2022-02-20 18:36:04.386860',
#   '2022-02-20 18:36:04.386861',
#   '51.134.5.159'),
#  (782,
#   'Amy Wilkins',
#   'stephaniejackson@howard.com',
#   '68444 Johnson Mountains Apt. 414\nSouth Maryland, NS N7N 9T7',
#   'Hunterview',
#   'Saskatchewan',
#   'Guinea-Bissau',
#   '(849) 449-3963 x303',
#   'Nihil numquam quos.',
#   '2001-06-08',
#   2041,
#   '2022-02-20 18:36:04.387943',
#   '2022-02-20 18:36:04.387944',
#   '123.175.72.172'),
#  (783,
#   'Colleen Espinoza',
#   'frostlaurie@hotmail.com',
#   '32882 Jerry Squares Apt. 183\nRonaldfurt, QC A9Y9A5',
#   'North Jonathan',
#   'Ontario',
#   'Guernsey',
#   '1-324-209-8227',
#   'Vel aliquam.',
#   '1940-05-11',
#   1836,
#   '2022-02-20 18:36:04.388856',
#   '2022-02-20 18:36:04.388857',
#   '101.62.207.38'),
#  (784,
#   'Rachael Crawford',
#   'frichards@hotmail.com',
#   '645 Richard Track Suite 840\nEast Stephenburgh, QC S2L4K9',
#   'South Stephenchester',
#   'Alberta',
#   'Zambia',
#   '1 (693) 507-5922',
#   'Dolorem non aliquid.',
#   '1976-09-16',
#   1175,
#   '2022-02-20 18:36:04.389700',
#   '2022-02-20 18:36:04.389701',
#   '22.165.119.208'),
#  (785,
#   'Omar Smith',
#   'kimberly11@hernandez.net',
#   '56181 Ward Mission\nSouth Angela, BC L4L 1M2',
#   'Charlesberg',
#   'Nova Scotia',
#   'Monaco',
#   '849.503.8297',
#   'Amet.',
#   '1950-04-27',
#   1107,
#   '2022-02-20 18:36:04.390620',
#   '2022-02-20 18:36:04.390621',
#   '161.228.71.115'),
#  (786,
#   'Patricia Davidson',
#   'angelabarnes@benton-olson.biz',
#   '88105 Brooks Stream\nAmymouth, AB E3J 7A3',
#   'Kristenton',
#   'Alberta',
#   'Cook Islands',
#   '(421) 096-1853',
#   'Quis officia ab.',
#   '1947-12-29',
#   2375,
#   '2022-02-20 18:36:04.391692',
#   '2022-02-20 18:36:04.391693',
#   '39.214.21.249'),
#  (787,
#   'Stephanie Atkins',
#   'mahoneylori@hotmail.com',
#   '1080 Mindy Bypass\nWest Jenniferland, QC B7G 9K2',
#   'West Keith',
#   'Northwest Territories',
#   'Cape Verde',
#   '(414) 014-1905 x688',
#   'Quod dicta quis.',
#   '1956-07-21',
#   2231,
#   '2022-02-20 18:36:04.392561',
#   '2022-02-20 18:36:04.392562',
#   '1.164.83.128'),
#  (788,
#   'Courtney Diaz',
#   'oyoung@hotmail.com',
#   '64637 Payne Overpass\nSamuelland, YT T4R1T3',
#   'Lake Virginia',
#   'Yukon Territory',
#   'Equatorial Guinea',
#   '+1 (801) 163-4334',
#   'Sequi voluptates.',
#   '1941-03-22',
#   2444,
#   '2022-02-20 18:36:04.393382',
#   '2022-02-20 18:36:04.393383',
#   '11.136.160.87'),
#  (789,
#   'Jerry Casey MD',
#   'charlesjohnson@andrews.org',
#   '1523 Williams Rest Apt. 407\nEast Suzanne, AB V2L 5T2',
#   'Dixonshire',
#   'Prince Edward Island',
#   'Canada',
#   '(889) 689-1763 x516',
#   'Nobis expedita.',
#   '1916-01-20',
#   1848,
#   '2022-02-20 18:36:04.394574',
#   '2022-02-20 18:36:04.394575',
#   '62.164.136.14'),
#  (790,
#   'Michael Bowen',
#   'kennethdavies@williams.com',
#   '96947 Aaron Center Suite 876\nEast Cynthiabury, NL K6B 5L6',
#   'Shannonton',
#   'Yukon Territory',
#   'Uganda',
#   '954 272 2549',
#   'Dolorum impedit unde.',
#   '1922-05-15',
#   1308,
#   '2022-02-20 18:36:04.395703',
#   '2022-02-20 18:36:04.395704',
#   '167.190.234.140'),
#  (791,
#   'Matthew Wilson',
#   'williamsstacey@yahoo.com',
#   '0877 Lowery Centers Apt. 184\nCooperbury, MB M2X6X1',
#   'Bruceland',
#   'Saskatchewan',
#   'Congo',
#   '727 156 5689',
#   'Aspernatur.',
#   '2006-12-03',
#   1459,
#   '2022-02-20 18:36:04.396654',
#   '2022-02-20 18:36:04.396655',
#   '100.200.150.181'),
#  (792,
#   'Michelle Randolph',
#   'pnguyen@jackson.com',
#   '212 Glass Forge Suite 117\nPort Breanna, BC E3V 5V6',
#   'North Troychester',
#   'Northwest Territories',
#   'Bermuda',
#   '1-866-574-1601',
#   'Reiciendis magni.',
#   '1946-02-12',
#   2152,
#   '2022-02-20 18:36:04.397765',
#   '2022-02-20 18:36:04.397766',
#   '96.98.217.139'),
#  (793,
#   'Anthony Gregory',
#   'donnabooth@gmail.com',
#   '928 Johnson Union Suite 113\nEast Kathyshire, NL L5T3B4',
#   'East Tim',
#   'Manitoba',
#   'Singapore',
#   '945 101 0120',
#   'Eius ullam ad.',
#   '2010-12-05',
#   1247,
#   '2022-02-20 18:36:04.398658',
#   '2022-02-20 18:36:04.398659',
#   '59.48.7.233'),
#  (794,
#   'Shane Baker',
#   'hlloyd@bryant-hernandez.com',
#   '65305 Kelly Islands Suite 136\nRaymondtown, NB S3P8H4',
#   'Port Gloria',
#   'Nova Scotia',
#   'Algeria',
#   '661.422.3758',
#   'Libero molestiae placeat.',
#   '1937-03-12',
#   1459,
#   '2022-02-20 18:36:04.399641',
#   '2022-02-20 18:36:04.399642',
#   '218.180.192.46'),
#  (795,
#   'Sara Warner',
#   'bmiller@hotmail.com',
#   '6975 Lopez Camp Apt. 214\nJenniferchester, NU V1C 6H2',
#   'Williamstad',
#   'Saskatchewan',
#   'Hong Kong',
#   '268-626-9220 x986',
#   'Aliquid error facilis.',
#   '1975-08-10',
#   1965,
#   '2022-02-20 18:36:04.400495',
#   '2022-02-20 18:36:04.400496',
#   '15.7.178.207'),
#  (796,
#   'Jeffrey Valencia',
#   'ralphflores@rice.net',
#   '2449 Allen Extension Apt. 528\nNorth Roy, MB R7H5P2',
#   'Romanshire',
#   'Prince Edward Island',
#   'Canada',
#   '+1 (860) 701-3449',
#   'Blanditiis ut.',
#   '1989-06-06',
#   2065,
#   '2022-02-20 18:36:04.401510',
#   '2022-02-20 18:36:04.401512',
#   '121.23.73.193'),
#  (797,
#   'Daniel Knight',
#   'zacharyfrazier@gmail.com',
# ...
#   '129.149.55.65'),
#  (951,
#   'Derek Torres',
#   'denisenelson@smith.com',
#   '503 Warren Passage\nJosephburgh, SK P2A4G6',
#   'Kimchester',
#   'Northwest Territories',
#   'Moldova',
#   '113 525 9611',
#   'Iure exercitationem.',
#   '1935-08-27',
#   1581,
#   '2022-02-20 18:36:04.569055',
#   '2022-02-20 18:36:04.569057',
#   '124.22.73.103'),
#  (952,
#   'Rachel Harris',
#   'carrie96@gmail.com',
#   '436 Kristin Pass Apt. 146\nWest Alan, ON L3H 5M9',
#   'South Katie',
#   'Yukon Territory',
#   'Yemen',
#   '+1 (159) 989-8785',
#   'Suscipit magnam.',
#   '2019-11-19',
#   1291,
#   '2022-02-20 18:36:04.569863',
#   '2022-02-20 18:36:04.569864',
#   '188.13.165.168'),
#  (953,
#   'Karina Smith',
#   'sanchezchristopher@gmail.com',
#   '4645 Holly Rue Apt. 530\nAcevedoton, MB T8T 1J5',
#   'South Susanberg',
#   'Prince Edward Island',
#   'United States Minor Outlying Islands',
#   '897-163-2573',
#   'Aliquid a veritatis laboriosam.',
#   '1924-05-18',
#   2140,
#   '2022-02-20 18:36:04.570767',
#   '2022-02-20 18:36:04.570769',
#   '137.210.98.39'),
#  (954,
#   'Michelle Gonzalez',
#   'wilkersonjacqueline@hotmail.com',
#   '7723 Lee Viaduct\nLake Jocelyn, YT S7A 1A6',
#   'Haroldtown',
#   'Ontario',
#   'Malawi',
#   '(733) 827-9092 x087',
#   'Consectetur.',
#   '2013-01-21',
#   1471,
#   '2022-02-20 18:36:04.571658',
#   '2022-02-20 18:36:04.571660',
#   '72.71.227.102'),
#  (955,
#   'Kevin Taylor',
#   'brandy76@hotmail.com',
#   '338 Joshua Landing\nSnydermouth, PE B8R1A4',
#   'Davidview',
#   'British Columbia',
#   'Paraguay',
#   '289-504-2727',
#   'Nobis quisquam labore.',
#   '1981-05-21',
#   1244,
#   '2022-02-20 18:36:04.572473',
#   '2022-02-20 18:36:04.572474',
#   '147.208.245.244'),
#  (956,
#   'Justin Mclean',
#   'amiller@hotmail.com',
#   '998 Randall Ports\nWest Johnmouth, SK X8M 9A9',
#   'West William',
#   'Saskatchewan',
#   'Philippines',
#   '1-572-728-4153',
#   'Labore animi.',
#   '1942-10-02',
#   1799,
#   '2022-02-20 18:36:04.573294',
#   '2022-02-20 18:36:04.573295',
#   '6.116.12.162'),
#  (957,
#   'Lori Huang',
#   'mcbridedenise@love-esparza.com',
#   '304 David Crest\nJosephshire, NT Y2L9A3',
#   'Port Ericton',
#   'Manitoba',
#   'Netherlands',
#   '923.524.6491',
#   'Dignissimos facilis perferendis.',
#   '1914-01-24',
#   2231,
#   '2022-02-20 18:36:04.574340',
#   '2022-02-20 18:36:04.574341',
#   '162.84.127.209'),
#  (958,
#   'Megan Carter',
#   'heidi17@lewis.info',
#   '99280 White Locks Suite 534\nMelaniefurt, ON M2P9E4',
#   'Parkerchester',
#   'Alberta',
#   'Moldova',
#   '740.648.9996',
#   'Iure minus quaerat.',
#   '1971-09-02',
#   1142,
#   '2022-02-20 18:36:04.575303',
#   '2022-02-20 18:36:04.575305',
#   '118.53.179.98'),
#  (959,
#   'Mary Sullivan',
#   'palmerlaura@hotmail.com',
#   '751 Robert Trail Apt. 840\nWhitakerborough, BC T5B4V8',
#   'Carterhaven',
#   'Ontario',
#   'Faroe Islands',
#   '341-847-6226',
#   'Nemo quos sequi.',
#   '1959-06-21',
#   2379,
#   '2022-02-20 18:36:04.576208',
#   '2022-02-20 18:36:04.576209',
#   '163.204.20.35'),
#  (960,
#   'Daniel Hodges',
#   'kgray@hotmail.com',
#   '89717 Allison Trail\nAnthonyborough, PE J3X4H2',
#   'East Stephanie',
#   'Northwest Territories',
#   'Russian Federation',
#   '804-393-2882',
#   'Ipsam consequatur consequuntur.',
#   '1989-12-27',
#   2289,
#   '2022-02-20 18:36:04.577031',
#   '2022-02-20 18:36:04.577032',
#   '72.64.164.189'),
#  (961,
#   'Valerie Vaughn',
#   'danielleonard@yahoo.com',
#   '719 Perkins Crest\nSouth Melissamouth, NU L4S 2Y8',
#   'Craneburgh',
#   'New Brunswick',
#   'Comoros',
#   '(726) 470-2078',
#   'Reprehenderit magnam commodi.',
#   '1992-01-26',
#   1155,
#   '2022-02-20 18:36:04.577946',
#   '2022-02-20 18:36:04.577948',
#   '125.184.226.106'),
#  (962,
#   'Edward Nguyen',
#   'eroach@wong.com',
#   '52478 Betty Drives\nWest Brittneyburgh, NU B4E 2S3',
#   'South Patrick',
#   'Alberta',
#   'Rwanda',
#   '1 (600) 258-8897',
#   'Possimus et maxime.',
#   '2016-06-25',
#   1438,
#   '2022-02-20 18:36:04.579015',
#   '2022-02-20 18:36:04.579016',
#   '155.253.251.137'),
#  (963,
#   'Dean Simmons',
#   'nmiller@gmail.com',
#   '5086 Jenny Avenue\nMonicaland, NS E2P 8J6',
#   'Holdenview',
#   'Ontario',
#   'United States Minor Outlying Islands',
#   '+1 (196) 361-2960',
#   'Quia ducimus.',
#   '2014-03-23',
#   2163,
#   '2022-02-20 18:36:04.579855',
#   '2022-02-20 18:36:04.579857',
#   '42.80.119.229'),
#  (964,
#   'Thomas Reeves',
#   'yballard@welch-salinas.com',
#   '80697 Anna Ford\nBowmanfurt, NT S6M 6E9',
#   'North Robert',
#   'Prince Edward Island',
#   'Lithuania',
#   '(210) 090-6034',
#   'Architecto praesentium.',
#   '2020-03-14',
#   2121,
#   '2022-02-20 18:36:04.580868',
#   '2022-02-20 18:36:04.580869',
#   '132.45.88.252'),
#  (965,
#   'Matthew Stewart',
#   'brendahoward@yahoo.com',
#   '63321 Peterson Skyway\nEast Michellehaven, AB C4B 2K3',
#   'Port Jennifer',
#   'Saskatchewan',
#   'Malawi',
#   '354-536-0049',
#   'Doloremque magnam perferendis.',
#   '1983-09-23',
#   2097,
#   '2022-02-20 18:36:04.581753',
#   '2022-02-20 18:36:04.581754',
#   '2.160.148.182'),
#  (966,
#   'Garrett Duarte',
#   'joan06@hotmail.com',
#   '75565 Joshua Loop\nPort Kristen, PE P6A1K2',
#   'Kirkside',
#   'Saskatchewan',
#   'United Arab Emirates',
#   '774-173-2303',
#   'Nemo dolorum pariatur.',
#   '1969-04-25',
#   1341,
#   '2022-02-20 18:36:04.582608',
#   '2022-02-20 18:36:04.582609',
#   '213.61.168.122'),
#  (967,
#   'Richard Lin',
#   'popeshannon@hotmail.com',
#   '38429 Dickerson Park\nSmithbury, AB B4Y3X7',
#   'Deanchester',
#   'British Columbia',
#   'Albania',
#   '(442) 980-3772 x896',
#   'Ducimus quod.',
#   '1968-06-18',
#   1398,
#   '2022-02-20 18:36:04.583549',
#   '2022-02-20 18:36:04.583550',
#   '169.83.52.70'),
#  (968,
#   'Cheryl Wilson',
#   'jamesramsey@price.com',
#   '9829 Rachel Tunnel\nJordanside, MB C9L 3L8',
#   'Markfurt',
#   'Alberta',
#   'Saint Lucia',
#   '777-040-7264',
#   'Animi nesciunt.',
#   '1992-04-15',
#   2269,
#   '2022-02-20 18:36:04.585002',
#   '2022-02-20 18:36:04.585003',
#   '16.129.152.75'),
#  (969,
#   'Kyle Smith',
#   'glarson@gmail.com',
#   '019 Jasmine Square Suite 114\nNorth Brianna, YT R9Y1P4',
#   'Scottport',
#   'Northwest Territories',
#   'Malta',
#   '(920) 277-7579',
#   'Ab porro repellat.',
#   '2009-04-26',
#   1326,
#   '2022-02-20 18:36:04.585971',
#   '2022-02-20 18:36:04.585972',
#   '101.149.234.99'),
#  (970,
#   'Michael Todd',
#   'tiffany27@gmail.com',
#   '3392 Francis Mall Suite 407\nLyonschester, NL X1V1N2',
#   'West Scott',
#   'Yukon Territory',
#   'New Caledonia',
#   '(537) 720-0618 x827',
#   'Excepturi porro recusandae.',
#   '1919-10-26',
#   2094,
#   '2022-02-20 18:36:04.586926',
#   '2022-02-20 18:36:04.586928',
#   '33.110.35.194'),
#  (971,
#   'Anthony Bush MD',
#   'anthony79@anderson.com',
#   '408 Swanson Camp\nAndreamouth, NU H1P 9P9',
#   'Melindamouth',
#   'New Brunswick',
#   'Montenegro',
#   '101-756-7136 x310',
#   'Velit voluptatem assumenda itaque.',
#   '1945-09-13',
#   1437,
#   '2022-02-20 18:36:04.588073',
#   '2022-02-20 18:36:04.588074',
#   '222.38.31.236'),
#  (972,
#   'Ronald Decker',
#   'reedleah@hotmail.com',
#   '08923 Michael Lodge\nSouth Victoriafurt, YT S7E1A6',
#   'Duaneport',
#   'Nunavut',
#   'Jordan',
#   '(183) 388-2618',
#   'Quaerat qui.',
#   '1983-11-12',
#   1548,
#   '2022-02-20 18:36:04.589075',
#   '2022-02-20 18:36:04.589077',
#   '90.4.155.20'),
#  (973,
#   'Shawn Johnson',
#   'luishill@king.com',
#   '45765 Lopez Plains\nWest Anna, SK V2J3E3',
#   'Reynoldsside',
#   'Nunavut',
#   'Sweden',
#   '(562) 394-3838',
#   'Veritatis dignissimos sunt.',
#   '1997-01-02',
#   1621,
#   '2022-02-20 18:36:04.590338',
#   '2022-02-20 18:36:04.590340',
#   '170.74.189.128'),
#  (974,
#   'Jason Mcdonald',
#   'zfoster@yahoo.com',
#   '35055 Robert Via\nSaraton, PE L1N 5L3',
#   'Andersonside',
#   'Nova Scotia',
#   'Haiti',
#   '1-511-299-5980',
#   'Ex corporis voluptatem.',
#   '1961-08-02',
#   2365,
#   '2022-02-20 18:36:04.591204',
#   '2022-02-20 18:36:04.591206',
#   '181.201.75.74'),
#  (975,
#   'Sheila Johnson',
#   'brownjoshua@yahoo.com',
#   '660 Reid Plain Suite 025\nNew Glenn, NS N7B9H5',
#   'Donnaborough',
#   'Ontario',
#   'Monaco',
#   '819-474-7174 x444',
#   'Exercitationem veritatis magni.',
#   '1932-03-22',
#   2170,
#   '2022-02-20 18:36:04.592562',
#   '2022-02-20 18:36:04.592563',
#   '153.66.17.100'),
#  (976,
#   'Margaret Peterson',
#   'kristagutierrez@yahoo.com',
#   '06917 Samantha Fort\nGregoryview, NL N1N 4Y2',
#   'West Tina',
#   'Nova Scotia',
#   'Kenya',
#   '+1 (384) 717-4798',
#   'Reiciendis excepturi distinctio.',
#   '1913-02-28',
#   1524,
#   '2022-02-20 18:36:04.593561',
#   '2022-02-20 18:36:04.593563',
#   '40.131.69.86'),
#  (977,
#   'Kristina Bright',
#   'udaniels@yahoo.com',
#   '1139 Walsh Rapid\nJamesburgh, SK Y2S 1X5',
#   'Timothyside',
#   'Northwest Territories',
#   'Sao Tome and Principe',
#   '1 (333) 787-5881',
#   'Dicta saepe.',
#   '1985-07-04',
#   1502,
#   '2022-02-20 18:36:04.594439',
#   '2022-02-20 18:36:04.594440',
#   '195.39.249.192'),
#  (978,
#   'Cody Perez',
#   'jerry38@gmail.com',
#   '1173 Jennifer Stream Apt. 402\nLaceyhaven, YT E6S9X2',
#   'Port Julieshire',
#   'Saskatchewan',
#   'Ecuador',
#   '+1 (539) 090-1164',
#   'Animi maiores soluta.',
#   '1974-08-12',
#   1786,
#   '2022-02-20 18:36:04.595282',
#   '2022-02-20 18:36:04.595284',
#   '50.0.132.102'),
#  (979,
#   'Hannah Bradley',
#   'brettsandoval@wright.org',
#   '7938 Susan Ranch\nEast Ashley, ON M5P5C1',
#   'North Randy',
#   'Saskatchewan',
#   'Palestinian Territory',
#   '512.438.2749',
#   'Nobis exercitationem.',
#   '1979-05-13',
#   2081,
#   '2022-02-20 18:36:04.596502',
#   '2022-02-20 18:36:04.596503',
#   '97.250.35.238'),
#  (980,
#   'Antonio Potts',
#   'nancybailey@martinez.com',
#   '8555 Jenkins Place Suite 795\nBrennanshire, MB N1J 6A8',
#   'Clarkland',
#   'Ontario',
#   'Belize',
#   '116-872-2232',
#   'Ab veniam.',
#   '1964-10-16',
#   1644,
#   '2022-02-20 18:36:04.597731',
#   '2022-02-20 18:36:04.597732',
#   '50.37.255.47'),
#  (981,
#   'Colleen Kemp',
#   'wsalazar@gmail.com',
#   '2012 Sabrina Falls\nSouth Derrick, BC R1V8V9',
#   'North Amy',
#   'Ontario',
#   'Senegal',
#   '918 954 0808',
#   'Earum iste.',
#   '1913-11-25',
#   1468,
#   '2022-02-20 18:36:04.598544',
#   '2022-02-20 18:36:04.598546',
#   '110.68.51.195'),
#  (982,
#   'Tina Rubio',
#   'barrycarlson@gmail.com',
#   '5383 Travis Place\nNorth Lindseyville, NT C6L 3V7',
#   'Port Ernest',
#   'British Columbia',
#   'France',
#   '961-502-9471',
#   'Maxime maxime.',
#   '1951-04-20',
#   2114,
#   '2022-02-20 18:36:04.599432',
#   '2022-02-20 18:36:04.599433',
#   '40.254.63.48'),
#  (983,
#   'Gary Waters',
#   'smithkathryn@allen.biz',
#   '772 Ryan Ports Apt. 232\nEast Rodneyburgh, PE L5B3V7',
#   'Jeffreyburgh',
#   'Yukon Territory',
#   'France',
#   '802.219.7925',
#   'Beatae cupiditate.',
#   '1916-03-30',
#   1088,
#   '2022-02-20 18:36:04.600425',
#   '2022-02-20 18:36:04.600426',
#   '107.138.193.116'),
#  (984,
#   'Aaron King',
#   'smithbrenda@powell-carr.biz',
#   '671 Fields Extension\nEast Jefferyport, AB X4L7J4',
#   'Margaretland',
#   'Nunavut',
#   'United States Minor Outlying Islands',
#   '(246) 188-6176',
#   'Animi similique.',
#   '1911-08-14',
#   1430,
#   '2022-02-20 18:36:04.601502',
#   '2022-02-20 18:36:04.601504',
#   '190.60.126.115'),
#  (985,
#   'Rose Garcia',
#   'jacqueline99@wagner.com',
#   '0149 Bond Summit Apt. 718\nNew Jennifer, AB R3T7R1',
#   'Marcushaven',
#   'Alberta',
#   'Palau',
#   '776-095-0191',
#   'Tenetur nihil aspernatur.',
#   '1920-09-12',
#   1971,
#   '2022-02-20 18:36:04.602487',
#   '2022-02-20 18:36:04.602488',
#   '90.254.15.101'),
#  (986,
#   'Brent Bryant',
#   'watsongary@hotmail.com',
#   '9465 Kelly Plain Apt. 909\nLake Brandi, AB S1L2M2',
#   'Port Shane',
#   'New Brunswick',
#   'Pakistan',
#   '772-264-1167',
#   'Magni illo aliquam.',
#   '1971-01-09',
#   2180,
#   '2022-02-20 18:36:04.603365',
#   '2022-02-20 18:36:04.603366',
#   '19.245.56.56'),
#  (987,
#   'Brent Lee',
#   'alexandra24@gmail.com',
#   '7795 Smith Crossroad\nWest Ashley, NT E5G6J6',
#   'North Lindsayton',
#   'British Columbia',
#   'Guinea-Bissau',
#   '327-632-9518',
#   'Cumque ut atque.',
#   '1908-01-30',
#   1869,
#   '2022-02-20 18:36:04.604179',
#   '2022-02-20 18:36:04.604181',
#   '213.80.194.40'),
#  (988,
#   'Desiree Smith DVM',
#   'andrew27@guzman.net',
#   '55146 Christopher Keys\nEast Larryfurt, BC N7V3A3',
#   'West Scott',
#   'Yukon Territory',
#   'Maldives',
#   '745-767-4537 x656',
#   'Quibusdam id.',
#   '2015-12-23',
#   1627,
#   '2022-02-20 18:36:04.605256',
#   '2022-02-20 18:36:04.605270',
#   '77.240.1.88'),
#  (989,
#   'Mitchell House',
#   'jonathon21@yahoo.com',
#   '009 Jessica Crest\nWest Allisonberg, PE Y4N7E6',
#   'New Brendaville',
#   'New Brunswick',
#   'Libyan Arab Jamahiriya',
#   '619-654-6910 x597',
#   'Officiis.',
#   '2004-07-14',
#   1939,
#   '2022-02-20 18:36:04.606042',
#   '2022-02-20 18:36:04.606044',
#   '35.65.155.163'),
#  (990,
#   'Daniel Porter',
#   'benjamin27@hotmail.com',
#   '846 Chapman Alley\nNew Mariestad, NU E2J8H2',
#   'Swansonmouth',
#   'Alberta',
#   'Germany',
#   '(868) 629-3930',
#   'Eos accusantium dignissimos.',
#   '1986-01-20',
#   2128,
#   '2022-02-20 18:36:04.606880',
#   '2022-02-20 18:36:04.606882',
#   '197.165.148.224'),
#  (991,
#   'Laura Hancock',
#   'amandahernandez@sims.com',
#   '61456 Trevino Field\nLake Anthony, ON L1H 3H3',
#   'Port Amanda',
#   'Prince Edward Island',
#   'Ukraine',
#   '+1 (587) 907-6408',
#   'Qui eligendi occaecati.',
#   '1911-06-12',
#   2041,
#   '2022-02-20 18:36:04.607875',
#   '2022-02-20 18:36:04.607876',
#   '63.211.94.206'),
#  (992,
#   'Sean Owens',
#   'andrew73@gmail.com',
#   '084 Joseph Village Apt. 601\nNorth Sarafurt, AB T4V 5T6',
#   'West Chelseafort',
#   'Nova Scotia',
#   'Uzbekistan',
#   '467-023-3199',
#   'Natus assumenda laboriosam.',
#   '1960-10-23',
#   2162,
#   '2022-02-20 18:36:04.608680',
#   '2022-02-20 18:36:04.608681',
#   '197.178.230.198'),
#  (993,
#   'Rebecca Moss',
#   'gnewman@cooper-thompson.com',
#   '062 Daniel Estates Apt. 588\nWilliamsmouth, ON S7B 6B8',
#   'Michaelberg',
#   'Alberta',
#   'Algeria',
#   '346.500.6700',
#   'Fuga in magni.',
#   '1932-08-03',
#   1020,
#   '2022-02-20 18:36:04.609726',
#   '2022-02-20 18:36:04.609727',
#   '168.75.67.178'),
#  (994,
#   'Vanessa Gonzalez',
#   'gregorymorris@baker.biz',
#   '65044 Tammy Crossing\nSanchezview, SK G7M6N9',
#   'Christopherfurt',
#   'New Brunswick',
#   'Christmas Island',
#   '483 480 5526',
#   'Sit.',
#   '1969-05-07',
#   2219,
#   '2022-02-20 18:36:04.610726',
#   '2022-02-20 18:36:04.610727',
#   '61.51.92.6'),
#  (995,
#   'Timothy Mitchell IV',
#   'adam57@yahoo.com',
#   '06199 Tara Mountains Apt. 838\nSouth Gregory, NS E8T 8H2',
#   'New Jason',
#   'Nunavut',
#   'Senegal',
#   '893-016-3044',
#   'Dignissimos magnam magnam.',
#   '2018-08-22',
#   1023,
#   '2022-02-20 18:36:04.611564',
#   '2022-02-20 18:36:04.611566',
#   '132.219.215.238'),
#  (996,
#   'Mr. Juan Townsend',
#   'racheljones@ward.org',
#   '69891 Annette Brooks Suite 506\nBergbury, AB K9V 2R8',
#   'Kellyport',
#   'Yukon Territory',
#   'Faroe Islands',
#   '516 761 7603',
#   'Voluptatem quia officia aperiam.',
#   '1991-11-07',
#   2183,
#   '2022-02-20 18:36:04.612582',
#   '2022-02-20 18:36:04.612583',
#   '1.95.118.184'),
#  (997,
#   'Alec Velasquez',
#   'gomezvictoria@terry.com',
#   '2193 Andrews Summit Apt. 653\nNew Maria, QC M2A1P2',
#   'West Melissa',
#   'British Columbia',
#   'Kyrgyz Republic',
#   '(865) 756-0676',
#   'Quibusdam animi voluptatibus.',
#   '1927-04-29',
#   2209,
#   '2022-02-20 18:36:04.613575',
#   '2022-02-20 18:36:04.613577',
#   '143.28.98.52'),
#  (998,
#   'Michele Ramsey',
#   'jill26@yahoo.com',
#   '785 Gina Spur Apt. 168\nSharonside, QC P5K 7B1',
#   'New Williamborough',
#   'Northwest Territories',
#   'Haiti',
#   '725-058-9393',
#   'Excepturi vel.',
#   '2003-08-19',
#   2476,
#   '2022-02-20 18:36:04.614378',
#   '2022-02-20 18:36:04.614379',
#   '104.237.32.227'),
#  (999,
#   'Catherine Yates',
#   'vcantu@yahoo.com',
#   '270 Eric Circles Apt. 740\nOconnellmouth, PE E7L 7M8',
#   'Jamesbury',
#   'Yukon Territory',
#   'Samoa',
#   '1 (551) 636-7337',
#   'Molestiae repudiandae consequuntur.',
#   '2001-08-21',
#   1418,
#   '2022-02-20 18:36:04.615211',
#   '2022-02-20 18:36:04.615213',
#   '75.36.66.218'),
#  (1000,
#   'Lisa Williams',
#   'phillip26@williams.com',
#   '973 Williamson Island\nSouth Mary, SK A9H 2P9',
#   'East Troyport',
#   'Yukon Territory',
#   'Iran',
#   '568-442-8390',
#   'Culpa delectus.',
#   '2019-11-04',
#   1941,
#   '2022-02-20 18:36:04.616128',
#   '2022-02-20 18:36:04.616130',
#   '108.167.42.123'),
#  (1001,
#   'Heather Harris',
#   'bethsmith@rivera.com',
#   '21740 Russell Skyway\nJuliafort, NT A6Y7P3',
#   'Lake Rebeccafort',
#   'Saskatchewan',
#   'Jordan',
#   '(519) 938-4801',
#   'Rem et.',
#   '1974-04-30',
#   2091,
#   '2022-02-20 18:36:04.617128',
#   '2022-02-20 18:36:04.617129',
#   '139.126.23.44')]

# %% [markdown]
# Finally, the last step,
# Using the code block below, combined with what you have learned above, and the Lecture notes,
# Craft a SQL Query that will return the `name` of no more than `20` `people` with a `heatmap` greater than `1500`

# %%
import sqlite3
from pprint import pprint
#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

# shows no more than 20 people who's heat map is higher than 1500
selectStatement = """SELECT name, heatmap FROM people WHERE heatmap > 1500 LIMIT 20"""

#excutes the select statement
myCursor.execute(selectStatement)

#prints the results of the select statment to the console
results= myCursor.fetchall()
pprint(results)

#closes the connection to the database
myConnection.close()
# Out:
# [('Damon Smith', 2157),
#  ('Breanna Reed', 1736),
#  ('Catherine Ramirez', 1977),
#  ('Allen Simpson', 1733),
#  ('Cody Turner', 2310),
#  ('Eric Miller DVM', 2463),
#  ('Lisa Graham', 2224),
#  ('Jaclyn Gutierrez', 1778),
#  ('Gabriel Parker', 1563),
#  ('Mark Robbins', 1771),
#  ('Isaac Hall', 1524),
#  ('Donna Welch', 1877),
#  ('Ashley Brock', 2196),
#  ('Adrian Mora', 1584),
#  ('Jamie Jones', 1676),
#  ('Rebecca Fletcher', 2378),
#  ('Kevin Garcia', 2421),
#  ('Nicole Brown', 1808),
#  ('Barry Wright', 2063),
#  ('Karl Jones', 1518)]

# %% [markdown]
# Your submission will contain, as usual, a link to your completed colab notebook, but in addition to that, you will download a copy of your social_network.db file and upload it to D2L. To download the file, right click it from the Files menu on the left of the Notebook.
