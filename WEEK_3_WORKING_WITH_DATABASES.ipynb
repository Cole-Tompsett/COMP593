# %% [markdown]
# <a href="https://colab.research.google.com/github/Cole-Tompsett/COMP593/blob/main/WEEK_3_WORKING_WITH_DATABASES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LAB 3: WORKING WITH DATABASES

# %% [markdown]
# ## Introduction
#
# During this lab, we will experiment with using a few different libararies and modules to connect to and interact with an SQLite database. After creating and configuring our testing database, we will populate it with Fake data and run some queries to see what kind of information we can retreive. For context, we will be creating RSSN, the "Really Simple Social Network".

# %% [markdown]
# ## Creating a SQLite Database
#
# We will be utilizing the `sqlite3` library to create our database file, as it offers the convienience of creating our database file automatically in the event that it cannot find an existing file at the path specified.
#
# **Before you run the below code:**
# On the left of the notebook, select the file folder icon. Then, after you run the code block, you should be able to observe the creation of the database file. If it doesn't appear, try clicking the "Refresh" button above the list of folders.

# %%
import sqlite3

#When we retreive a Connection object, a new database will be created for us if it doesn't already exist. 
myConnection = sqlite3.connect('social_network.db')
print(sqlite3.version)
# Out:
# 2.6.0

# %% [markdown]
# ## Creating a Table

# %% [markdown]
# We'll use the below code to create a table called `people` within our database.

# %%
import sqlite3

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Let's define the SQL Query we will use to create our first table:
createPeopleTable = """ CREATE TABLE IF NOT EXISTS people (
                          id integer PRIMARY KEY,
                          name text NOT NULL,
                          email text NOT NULL,
                          address text NOT NULL,
                          city text NOT NULL,
                          province text NOT NULL,
                          country text NOT NULL,
                          phone text,
                          bio text,
                          dob date NOT NULL,
                          heatmap integer,
                          created_at datetime NOT NULL,
                          updated_at datetime NOT NULL,
                          ipv4 text
                        );"""

#Now that we have the string to create our table,
#Cursor objects have an execute() method which will accept an SQL string and perform the operations described.

myCursor.execute(createPeopleTable)

#We can confirm if our table was created successfully by running the following SQL Query
#pragma_table_info is an internal SQLite function that will retun information about a table
myCursor.execute("SELECT group_concat(name, ', ') FROM pragma_table_info('people')")
print(myCursor.fetchone())

#We use to the commit() method on the database Connection object to persist our changes
myConnection.commit()

#It is always a good idea to close a connection when it will no longer be used
myConnection.close()
# Out:
# ('id, name, email, address, city, province, country, phone, bio, dob, heatmap, created_at, updated_at, ipv4',)

# %% [markdown]
# If you received a tuple containing the names of the columns, awesome! We have successfully created our database table.
# ```
# ('id, name, email, address, city, province, country, phone, bio, created_at, updated_at',)
# ```
#
# Run the below code block to add our first entry.

# %%
import sqlite3
from pprint import pprint #Outputs data in a slightly easier to read format
from datetime import datetime #For generating dates and times

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#Let's define the SQL Query we will use to create our first entry:
addPersonQuery = """INSERT INTO people (name, 
                      email, 
                      address, 
                      city, 
                      province, 
                      country, 
                      phone, 
                      bio,
                      dob,
                      heatmap,
                      created_at, 
                      updated_at, 
                      ipv4)
                  VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?);"""

"""
The ?'s are placeholders that we can fill in when we use the execute() method.
This is really handy for code reuse, as we can pass those values are variables in a tuple
Instead of hard coding them into the statement.
"""

myPerson = ("John Doe", 
            "johndoe@anon.null", 
            "123 Fake St.", 
            "Fakesville", 
            "Fakesdom", 
            "Fakopolis", 
            None, 
            None,
            "1967-09-12",
            0,
            datetime.now(), 
            datetime.now(),
            None)

myCursor.execute(addPersonQuery, myPerson)

#We can confirm if our table was created successfully by running the following SQL Query
#pragma_table_info is an internal SQLite function that will retun information about a table
myCursor.execute("SELECT * FROM people")
pprint(myCursor.fetchall())

# If you run this code block a few times, you will see that you only have 1 entry,
# If you uncomment the below lines and run the block a few more times, you will begin to see multiple entries.
myConnection.commit()
myConnection.close()
# Out:
# [(1,
#   'John Doe',
#   'johndoe@anon.null',
#   '123 Fake St.',
#   'Fakesville',
#   'Fakesdom',
#   'Fakopolis',
#   None,
#   None,
#   '1967-09-12',
#   0,
#   '2022-02-20 17:55:10.723838',
#   '2022-02-20 17:55:10.723854',
#   None)]

# %% [markdown]
# # Lab Submission

# %% [markdown]
# We're going to build our experience with working with Libraries and examining documentation by populating our 'People' table with data provided to us by the `Faker` library. `Faker` is used to generate fake data and is very helpful for the rapid generation of databases for the purposes of testing. Run the two blocks below to install faker and get an idea of what it can do.

# %%
# !pip install faker
# Out:
# Requirement already satisfied: faker in /usr/local/lib/python3.7/dist-packages (13.0.0)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.7/dist-packages (from faker) (2.8.2)
# Requirement already satisfied: typing-extensions>=3.10.0.2 in /usr/local/lib/python3.7/dist-packages (from faker) (3.10.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.4->faker) (1.15.0)

# %%
from faker import Faker

fake = Faker()

for _ in range(10):
  print('{} || {}'.format( fake.name(), fake.job() ) )
# Out:
# Deborah Reed || Stage manager
# Damon Stark || Chartered accountant
# Robert Yang || Air broker
# Jacqueline Washington || Forest/woodland manager
# Theresa Hall || Community pharmacist
# Sarah Singh || Landscape architect
# Michael Nguyen || Therapist, drama
# Kelly Acosta || Health visitor
# Courtney Acosta || Politician's assistant
# Amy West || Clinical molecular geneticist

# %% [markdown]
# Very cool! Faker has tons of `providers` that can all be used to populate fake data. The [list of providers](https://faker.readthedocs.io/en/stable/providers.html) in the Faker documentation will help you fill out the columns for our People table.
#
# The goal of this script is to populate the people table with 1000 entries, with the following constraints:
#
# 1. The `heatmap` column must contain a random number between `999` and `2500`
# 2. The `created_at` and `updated_at` columns must use the `datetime` object (see examples above)
# 2. Use `Faker` to generate all other fields.
#
# *Hint: Each of the methods contained in the provider can be called directly from the base Faker object, for example, one can call the `file_name()` method from `faker.providers.file` by calling `Faker().file_name()`*

# %%
import sqlite3
from faker import Faker
from pprint import pprint
from datetime import datetime #For generating dates and times
#Don't forget to import the module to generate random numbers!

#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

#This is the same syntax as the above example:
addPersonQuery = """INSERT INTO people (name, 
                      email, 
                      address, 
                      city, 
                      province, 
                      country, 
                      phone, 
                      bio,
                      dob,
                      heatmap,
                      created_at, 
                      updated_at, 
                      ipv4)
                  VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?);"""

fake = Faker("en_CA")
for person in range(1000):
  myPerson= (fake.name(), 
              fake.ascii_email(), 
              fake.address(), 
              fake.city(), 
              fake.administrative_unit(),
              fake.country(),
              fake.phone_number(),
              fake.sentence(nb_words = 30),
              fake.date_of_birth(),
              fake.random_int(min=999, max =2500),
              datetime.now(), 
              datetime.now(),
              fake.ipv4())

  myCursor.execute(addPersonQuery, myPerson)



myCursor.execute("SELECT * FROM people")
pprint(myCursor.fetchall())


myConnection.commit()
myConnection.close()
#Ideally, you will want to create a loop that will iterate 1000 times,
#Observe the example in the earlier code block showing the parameter tuple `myPerson`
#You can duplicate that inside your loop and replace those fields with calls to the appropriate faker provider method
#Execute your statement inside the loop,
#But, don't forget to commit and close your connection when you have finished!
# Out:
# Streaming output truncated to the last 5000 lines.
#   'Nunavut',
#   'Holy See (Vatican City State)',
#   '599-787-1044',
#   'Maiores excepturi eius itaque animi veniam tempore corporis veniam fugit '
#   'aut officia consequatur distinctio distinctio dolore fuga nihil.',
#   '1985-12-24',
#   2385,
#   '2022-02-20 18:31:41.234399',
#   '2022-02-20 18:31:41.234400',
#   '97.134.153.147'),
#  (2706,
#   'Samantha Cain',
#   'qmckee@ibarra.com',
#   '7203 Freeman Forge Suite 519\nBennettport, MB Y7X 4L2',
#   'Robinborough',
#   'Newfoundland and Labrador',
#   'Algeria',
#   '110-237-1596',
#   'Velit deleniti expedita omnis tenetur nesciunt alias necessitatibus rem '
#   'voluptate animi nulla consequuntur quasi tempora consequatur quos nesciunt '
#   'quo at amet occaecati aut in corrupti beatae fuga doloribus voluptatum '
#   'illum voluptatibus molestias voluptates dicta accusamus asperiores '
#   'provident quod deleniti.',
#   '1952-10-15',
#   2109,
#   '2022-02-20 18:31:41.235529',
#   '2022-02-20 18:31:41.235531',
#   '149.38.40.23'),
#  (2707,
#   'Jessica Daniel',
#   'richard98@wood.com',
#   '778 Lewis Road Suite 081\nRyanmouth, NT E3J 7N9',
#   'Reneestad',
#   'Alberta',
#   'Vietnam',
#   '213-181-3193',
#   'Earum esse aspernatur nemo dolor excepturi animi modi magnam neque hic '
#   'explicabo placeat praesentium sit saepe vitae dolores id pariatur '
#   'voluptatum rerum exercitationem eveniet sunt non commodi unde aut delectus '
#   'temporibus eos sint aut corporis commodi.',
#   '1979-08-10',
#   2044,
#   '2022-02-20 18:31:41.236462',
#   '2022-02-20 18:31:41.236463',
#   '17.9.3.143'),
#  (2708,
#   'James Martin',
#   'thomas12@yahoo.com',
#   '5146 Barnes Estate Suite 737\nSouth Ronnie, NL N3K 2S4',
#   'West Amybury',
#   'New Brunswick',
#   'Afghanistan',
#   '695-876-8016 x366',
#   'Recusandae mollitia libero mollitia non dicta harum alias odio quam beatae '
#   'quaerat sit vel voluptatibus quidem sint autem beatae laboriosam esse '
#   'accusamus temporibus soluta vel dolor ut ab qui doloremque cupiditate.',
#   '2010-10-03',
#   1903,
#   '2022-02-20 18:31:41.237300',
#   '2022-02-20 18:31:41.237302',
#   '81.9.59.247'),
#  (2709,
#   'Logan Williams',
#   'stevenwilliams@gmail.com',
#   '0839 Dawn Ramp\nWest Tina, NB T9N9C3',
#   'Alvarezborough',
#   'British Columbia',
#   'Antarctica (the territory South of 60 deg S)',
#   '802-746-4286',
#   'Iure veritatis atque id distinctio dolores debitis pariatur porro modi '
#   'commodi eum exercitationem ad nemo nobis laudantium placeat inventore esse '
#   'voluptatibus assumenda accusamus excepturi molestias ea quisquam recusandae '
#   'voluptate dolore.',
#   '1908-12-19',
#   2413,
#   '2022-02-20 18:31:41.238344',
#   '2022-02-20 18:31:41.238346',
#   '181.100.235.115'),
#  (2710,
#   'Michelle Wise',
#   'hramirez@white.com',
#   '342 Aguirre Plains\nEast Daniel, ON K4M 2G4',
#   'North Cindy',
#   'Nova Scotia',
#   'Dominica',
#   '793-537-6275 x529',
#   'Sit quis architecto odio exercitationem harum maiores modi rem alias '
#   'occaecati molestiae cumque ab cumque quod quisquam a rerum excepturi '
#   'commodi alias reprehenderit aliquam aperiam fuga cupiditate.',
#   '1964-01-09',
#   1459,
#   '2022-02-20 18:31:41.239291',
#   '2022-02-20 18:31:41.239292',
#   '215.205.235.33'),
#  (2711,
#   'William Collins',
#   'whitegary@hotmail.com',
#   '15105 Janet Drives Suite 540\nPort Elizabethfort, NU C2H 1Y1',
#   'Stephenview',
#   'Manitoba',
#   'Netherlands',
#   '852-150-6847 x604',
#   'Nesciunt rerum consectetur aliquid quae reprehenderit corrupti reiciendis '
#   'qui incidunt quibusdam molestias occaecati illum non impedit ut blanditiis '
#   'consectetur aliquam nisi provident dicta maxime magni dignissimos corporis '
#   'ea dicta molestiae quos eaque rerum sunt est ipsam repudiandae dicta '
#   'impedit.',
#   '1919-02-08',
#   2454,
#   '2022-02-20 18:31:41.240163',
#   '2022-02-20 18:31:41.240164',
#   '68.238.121.209'),
#  (2712,
#   'Alicia Moore DDS',
#   'michaelharris@martinez-howell.biz',
#   '365 Brian Burg Suite 287\nCastrochester, NU K5R 1X5',
#   'East Jessetown',
#   'Prince Edward Island',
#   'Puerto Rico',
#   '1 (508) 612-7165',
#   'Repellendus dolorem veritatis fuga sed perferendis esse natus officiis '
#   'asperiores reiciendis dignissimos mollitia reprehenderit reiciendis '
#   'doloribus soluta rerum.',
#   '1946-11-03',
#   2109,
#   '2022-02-20 18:31:41.241249',
#   '2022-02-20 18:31:41.241250',
#   '215.109.178.135'),
#  (2713,
#   'Lisa Davis',
#   'davisjustin@gmail.com',
#   '67608 Julia Walk Suite 266\nGeorgeside, QC X8C 7C8',
#   'Ramirezland',
#   'Quebec',
#   'Djibouti',
#   '497-607-1377',
#   'Eos nemo quam consectetur perferendis expedita similique earum quis '
#   'consequatur repudiandae maxime tenetur laborum repudiandae maiores illum '
#   'corrupti commodi.',
#   '1996-05-30',
#   1890,
#   '2022-02-20 18:31:41.242185',
#   '2022-02-20 18:31:41.242186',
#   '70.227.164.162'),
#  (2714,
#   'Kelly Lyons',
#   'karenthomas@gmail.com',
#   '183 Margaret Stravenue Apt. 686\nNorth Tara, ON B1R2J1',
#   'Port Karenstad',
#   'Alberta',
#   'Equatorial Guinea',
#   '+1 (143) 235-5763',
#   'Pariatur officiis nulla consequuntur ducimus repudiandae nulla quas eius '
#   'iusto neque sed corporis praesentium voluptate quo voluptates temporibus '
#   'sunt ad voluptates nostrum magnam reprehenderit iste sapiente veniam.',
#   '1941-08-06',
#   1756,
#   '2022-02-20 18:31:41.243070',
#   '2022-02-20 18:31:41.243071',
#   '57.51.200.223'),
#  (2715,
#   'Thomas Clarke',
#   'aguirreleslie@crawford.net',
#   '2576 Joe Lights\nNorth Zachary, NT Y4T8P9',
#   'Hayneschester',
#   'Quebec',
#   'Hong Kong',
#   '+1 (666) 145-0873',
#   'Eum laboriosam error voluptates nesciunt soluta exercitationem earum '
#   'dolores magni accusantium aliquam corporis quaerat cumque in voluptate '
#   'rerum eum eveniet necessitatibus dolor error aliquam enim animi delectus '
#   'sequi corporis temporibus neque qui ad cumque perspiciatis aspernatur '
#   'deserunt eveniet saepe adipisci quod.',
#   '2009-11-16',
#   1036,
#   '2022-02-20 18:31:41.244283',
#   '2022-02-20 18:31:41.244284',
#   '122.71.255.198'),
#  (2716,
#   'Nicholas Jones Jr.',
#   'angela07@buchanan.info',
#   '20139 Roberts Roads\nMitchellborough, NL L7G 7R8',
#   'Codyton',
#   'New Brunswick',
#   'Seychelles',
#   '397.235.1612',
#   'Cumque eligendi vel vel nihil totam libero vel sunt fugiat nihil occaecati '
#   'veniam sapiente soluta cum expedita doloribus voluptates eius.',
#   '1995-11-06',
#   1775,
#   '2022-02-20 18:31:41.245284',
#   '2022-02-20 18:31:41.245285',
#   '155.7.173.40'),
#  (2717,
#   'Henry Wells',
#   'christy50@sutton.com',
#   '21064 Guerra Hills Apt. 555\nAllisonmouth, SK Y9X9L3',
#   'East Angelica',
#   'Quebec',
#   'Fiji',
#   '(220) 056-7262',
#   'Dolor reiciendis distinctio facere eum ex veniam repudiandae odio iusto '
#   'corrupti maxime eos vero sint ullam natus nemo odio fuga perferendis ad '
#   'culpa natus suscipit laborum tempore nobis officiis asperiores.',
#   '1906-12-20',
#   1027,
#   '2022-02-20 18:31:41.246288',
#   '2022-02-20 18:31:41.246289',
#   '27.58.191.24'),
#  (2718,
#   'Brooke Stanley',
#   'matthew29@gmail.com',
#   '853 Rice Ranch Suite 169\nWest Angelbury, NB V9S 8P2',
#   'North Ashleymouth',
#   'Quebec',
#   'Tonga',
#   '1 (829) 526-6697',
#   'Repellendus iure iusto voluptate optio fuga aperiam magnam similique '
#   'distinctio eum ab impedit officiis at excepturi magnam debitis alias '
#   'perspiciatis expedita optio accusantium fugit dolor soluta rem aliquid '
#   'molestiae ratione molestias blanditiis maxime eum et sit at earum maxime.',
#   '1987-12-09',
#   1212,
#   '2022-02-20 18:31:41.247478',
#   '2022-02-20 18:31:41.247479',
#   '118.97.1.35'),
#  (2719,
#   'Kelly Bush',
#   'andrewashley@petersen-obrien.net',
#   '408 Shannon Lodge\nKaitlynport, QC R8S 5T5',
#   'Hughesstad',
#   'Prince Edward Island',
#   'El Salvador',
#   '(461) 701-2081',
#   'Rerum nulla veritatis laudantium odio consequuntur sed in quibusdam '
#   'assumenda nemo eius aspernatur recusandae atque quaerat molestiae qui '
#   'voluptatem animi reprehenderit vel facere eaque eius tempora quas dolores '
#   'expedita.',
#   '1994-02-14',
#   1949,
#   '2022-02-20 18:31:41.248559',
#   '2022-02-20 18:31:41.248561',
#   '78.79.242.238'),
#  (2720,
#   'Nancy Ward',
#   'petersnicole@yahoo.com',
#   '325 Andrew Gardens Suite 037\nAlexhaven, PE B9M9A2',
#   'Englishside',
#   'Manitoba',
#   'Nauru',
#   '141-324-2719 x408',
#   'Pariatur ratione dolore vitae impedit nesciunt ipsam odio cumque minus '
#   'atque pariatur natus eligendi voluptates expedita sapiente voluptate eos '
#   'dolor ullam ipsam eaque inventore reprehenderit quaerat asperiores facilis '
#   'at libero iure a sapiente molestiae nulla doloribus exercitationem earum '
#   'impedit iste.',
#   '1917-10-16',
#   2149,
#   '2022-02-20 18:31:41.249469',
#   '2022-02-20 18:31:41.249471',
#   '203.122.99.140'),
#  (2721,
#   'Kristopher Price',
#   'tiffanyvargas@henderson.com',
#   '3360 Stevens Overpass\nSouth Jennifer, NT R1B 1P7',
#   'Nathanielville',
#   'New Brunswick',
#   'Dominica',
#   '950.189.0659',
#   'Dolore sit illo ducimus adipisci facere odit nam vero facere amet delectus '
#   'voluptatem maiores porro natus deserunt consectetur assumenda similique '
#   'ratione molestias saepe excepturi necessitatibus rerum sequi inventore '
#   'voluptas officia vitae itaque veniam commodi sit.',
#   '1944-02-16',
#   1849,
#   '2022-02-20 18:31:41.250596',
#   '2022-02-20 18:31:41.250598',
#   '108.59.39.246'),
#  (2722,
#   'Eric Fernandez',
#   'atkinsmary@hotmail.com',
#   '13695 Logan Street\nMatthewtown, NS M7J5V1',
#   'East Williamborough',
#   'Newfoundland and Labrador',
#   'Pakistan',
#   '746-590-8937',
#   'Facere veniam facilis rerum quis similique at voluptatem hic impedit nemo '
#   'consequatur ea repudiandae consectetur laudantium nisi labore est fuga '
#   'autem rem fugit impedit temporibus error facere placeat doloremque esse '
#   'voluptate architecto minus sit id recusandae.',
#   '2002-01-30',
#   1292,
#   '2022-02-20 18:31:41.251479',
#   '2022-02-20 18:31:41.251480',
#   '11.189.92.145'),
#  (2723,
#   'Tiffany Cohen',
#   'hilljacob@hotmail.com',
#   '899 Michelle Lake\nPort Candace, BC K4M8J5',
#   'Knightfort',
#   'Prince Edward Island',
#   'Gabon',
#   '1 (394) 176-8110',
#   'Ipsa eos sed aut odio eveniet placeat et repellat omnis nemo aperiam '
#   'similique explicabo laborum exercitationem vitae provident explicabo non '
#   'inventore occaecati natus saepe reprehenderit modi eaque delectus soluta '
#   'porro quae ipsa hic impedit repellendus repellendus beatae consectetur '
#   'expedita.',
#   '1997-09-04',
#   1902,
#   '2022-02-20 18:31:41.252347',
#   '2022-02-20 18:31:41.252348',
#   '96.191.134.54'),
#  (2724,
#   'Alexis Kirk',
#   'cwoods@hotmail.com',
#   '94007 Shawn Fall Suite 094\nRosalesville, NU K5N 7L4',
#   'East Soniaborough',
#   'Nova Scotia',
#   'Suriname',
#   '(536) 576-6717 x982',
#   'Fuga nemo quod occaecati voluptatibus cupiditate ducimus fugit architecto '
#   'labore occaecati optio suscipit nesciunt officia minus voluptas vel '
#   'inventore corrupti iure totam eum labore molestiae eaque architecto alias '
#   'quis sapiente fuga molestias exercitationem adipisci aliquam maxime ipsam '
#   'ullam.',
#   '1939-01-27',
#   1109,
#   '2022-02-20 18:31:41.253189',
#   '2022-02-20 18:31:41.253190',
#   '206.153.52.132'),
#  (2725,
#   'Katherine Brown',
#   'carpentertara@gmail.com',
#   '65365 Tammie Underpass\nStokesfort, SK P6M 2R4',
#   'New Ronaldchester',
#   'Saskatchewan',
#   'San Marino',
#   '875-705-6407',
#   'Alias rerum vitae ipsum unde asperiores vel vitae similique hic laborum '
#   'repudiandae repudiandae dolorum suscipit praesentium quaerat minus.',
#   '1938-06-01',
#   2338,
#   '2022-02-20 18:31:41.254087',
#   '2022-02-20 18:31:41.254088',
#   '183.63.81.235'),
#  (2726,
#   'Carlos Roach',
#   'obell@gmail.com',
#   '53588 Kennedy Streets\nPayneshire, NS X7C7T2',
#   'Lake Kellyfort',
#   'New Brunswick',
#   'Bhutan',
#   '547 957 8550',
#   'Et ut possimus inventore rerum consequuntur dolorum deserunt eligendi '
#   'quidem saepe consequuntur debitis debitis laborum rerum adipisci tempora '
#   'officiis ab sit quisquam placeat tenetur neque.',
#   '1976-10-21',
#   1154,
#   '2022-02-20 18:31:41.254946',
#   '2022-02-20 18:31:41.254948',
#   '201.113.231.29'),
#  (2727,
#   'Michelle Carter',
#   'eric43@gmail.com',
#   '3789 Richard Point Apt. 621\nJeremychester, SK R1S 7P4',
#   'East Ashlee',
#   'British Columbia',
#   'Latvia',
#   '+1 (594) 800-4658',
#   'Vero autem odio distinctio nihil delectus dicta vitae pariatur minima unde '
#   'et qui atque repellendus quaerat velit fugit cumque magni doloribus magni '
#   'maiores ab veniam corrupti mollitia rem et incidunt voluptatibus dolor a '
#   'reiciendis corporis molestiae voluptatum.',
#   '1929-08-29',
#   1660,
#   '2022-02-20 18:31:41.255967',
#   '2022-02-20 18:31:41.255969',
#   '57.112.6.10'),
#  (2728,
#   'Linda Yoder',
#   'lynchsusan@johnson-barrett.com',
#   '42943 Ferguson Well\nLisashire, NT V2E1X5',
#   'Connortown',
#   'Saskatchewan',
#   'Turkey',
#   '670.210.3025',
#   'Dolorem dolor commodi neque quo distinctio maiores incidunt laudantium '
#   'delectus aut a illum aliquam fugiat officiis vitae veritatis minima odio ut '
#   'qui dolore saepe quisquam animi adipisci consequuntur fuga dicta nobis et '
#   'recusandae dolores molestias consequuntur voluptatem est.',
#   '2016-12-22',
#   2065,
#   '2022-02-20 18:31:41.257207',
#   '2022-02-20 18:31:41.257208',
#   '12.136.62.208'),
#  (2729,
#   'William Moss',
#   'richardshea@gmail.com',
#   '50922 Johnson Port\nPort Rickymouth, SK G3X 6J8',
#   'Harrisonchester',
#   'New Brunswick',
#   'Czech Republic',
#   '(878) 281-3128',
#   'Tenetur in rerum saepe porro officiis nihil magnam debitis consectetur sit '
#   'veniam aperiam illum voluptatibus iure tempora beatae iure ex neque itaque '
#   'veniam deleniti.',
#   '1932-06-24',
#   1360,
#   '2022-02-20 18:31:41.258163',
#   '2022-02-20 18:31:41.258165',
#   '91.135.227.189'),
#  (2730,
#   'Misty Lucas',
#   'john66@gmail.com',
#   '54627 Robert Port\nDouglasside, NU R4E6G8',
#   'Lake Richard',
#   'Nova Scotia',
#   'Ireland',
#   '810.985.1470',
#   'Optio id magnam voluptatem nobis doloremque optio deleniti esse corporis '
#   'vel blanditiis laboriosam quae veniam quaerat repellat dignissimos neque '
#   'minus expedita eveniet hic enim sapiente omnis odit debitis maiores impedit '
#   'illo accusantium voluptatibus.',
#   '1915-12-22',
#   2282,
#   '2022-02-20 18:31:41.258983',
#   '2022-02-20 18:31:41.258984',
#   '206.234.146.15'),
#  (2731,
#   'Brandon Krueger',
#   'ericreyes@yahoo.com',
#   '204 Joshua Villages Suite 116\nKleinstad, QC L9C6J7',
#   'Stacyberg',
#   'Prince Edward Island',
#   'Belize',
#   '1 (581) 483-9666',
#   'Ab hic exercitationem at atque cupiditate provident dolorem sint veritatis '
#   'labore aliquid dolor sed error sint ratione illum at facere laudantium '
#   'similique atque error perspiciatis unde.',
#   '1985-05-03',
#   2370,
#   '2022-02-20 18:31:41.259894',
#   '2022-02-20 18:31:41.259896',
#   '79.198.17.92'),
#  (2732,
#   'Thomas Watkins',
#   'ryan26@black.com',
#   '303 Yvette Curve\nNorth Lisa, AB H6P 1J8',
#   'Hamiltonton',
#   'British Columbia',
#   'Marshall Islands',
#   '424-268-9306 x593',
#   'Illo ea veniam voluptates sed placeat ab ab dolorem perferendis facilis '
#   'saepe officiis magni nulla doloremque distinctio voluptas nesciunt '
#   'molestiae neque alias reiciendis magni dolor molestiae nostrum quae.',
#   '1993-08-19',
#   1529,
#   '2022-02-20 18:31:41.260997',
#   '2022-02-20 18:31:41.260999',
#   '26.125.60.164'),
#  (2733,
#   'Daniel Miller',
#   'kelly80@hotmail.com',
#   '581 Mcconnell Valley Suite 726\nSouth Benjamin, NB L5E 2H8',
#   'Alexandrashire',
#   'Northwest Territories',
#   'Iran',
#   '(385) 990-7128 x112',
#   'Itaque eos quod beatae rerum rem corrupti enim totam fugit eum amet aliquam '
#   'deleniti itaque nemo fugiat saepe totam officia provident dolor ipsum quam '
#   'ab eveniet illo fugiat veritatis magnam perspiciatis culpa voluptatibus '
#   'officiis perferendis mollitia.',
#   '1995-05-26',
#   1805,
#   '2022-02-20 18:31:41.261875',
#   '2022-02-20 18:31:41.261876',
#   '7.189.107.187'),
#  (2734,
#   'Crystal Reese',
#   'vhamilton@yahoo.com',
#   '22785 Mackenzie Stream\nPorterbury, SK S3H1H8',
#   'South Matthewbury',
#   'Ontario',
#   'Bermuda',
#   '434-258-0304 x723',
#   'Saepe occaecati nostrum saepe ullam molestiae repellat tempore nisi debitis '
#   'inventore maiores veritatis voluptates tenetur nihil libero aliquid '
#   'aspernatur repellendus ut consequatur cumque.',
#   '1954-09-04',
#   2120,
#   '2022-02-20 18:31:41.262750',
#   '2022-02-20 18:31:41.262751',
#   '216.213.19.126'),
#  (2735,
#   'Jacqueline Powell',
#   'samantha27@hernandez.com',
#   '41921 Orr Mission Suite 975\nLake Davidfurt, NL X5V 7R8',
#   'Robertland',
#   'New Brunswick',
#   'Malaysia',
#   '682-095-3938',
#   'Minus animi placeat beatae amet ex fugiat ab aliquam sequi quibusdam cumque '
#   'vel maiores iure numquam voluptatibus iste id maiores recusandae.',
#   '1999-10-11',
#   1314,
#   '2022-02-20 18:31:41.263706',
#   '2022-02-20 18:31:41.263707',
#   '194.241.25.175'),
#  (2736,
#   'Mary Smith',
#   'timothy82@burke-everett.com',
#   '4437 Johnathan Hollow\nKimchester, NU A4L8R5',
#   'Austinfort',
#   'British Columbia',
#   'Marshall Islands',
#   '1 (119) 497-2654',
#   'Sint quod cum unde deserunt consequuntur est odit quos accusamus quasi ea '
#   'deleniti dignissimos tempore nobis harum quae illo aliquam explicabo itaque '
#   'animi dicta soluta soluta placeat assumenda perferendis exercitationem '
#   'tempora impedit aspernatur nam magni maiores molestiae corporis quod quod '
#   'fuga.',
#   '1951-01-04',
#   2009,
#   '2022-02-20 18:31:41.264719',
#   '2022-02-20 18:31:41.264721',
#   '109.209.229.220'),
#  (2737,
#   'Melissa Webster',
#   'eramsey@hotmail.com',
#   '699 Evan Drive Suite 150\nGaryview, PE E1L 4C7',
#   'Arellanoberg',
#   'New Brunswick',
#   'Mauritius',
#   '830-313-6123',
#   'Id maiores tenetur suscipit sequi magnam repellat ipsa adipisci facilis '
#   'molestias cum illo nulla quam quas nulla similique totam nostrum magnam sit '
#   'veritatis animi saepe sunt aut sapiente error porro reprehenderit odit '
#   'magni in fuga itaque.',
#   '2013-06-12',
#   1829,
#   '2022-02-20 18:31:41.265580',
#   '2022-02-20 18:31:41.265582',
#   '164.123.52.238'),
#  (2738,
#   'Katrina Graham',
#   'austin29@monroe-hill.org',
#   '42853 Atkins Shore\nGoldenville, NT V7C 8E7',
#   'Ninaberg',
#   'New Brunswick',
#   'Nauru',
#   '1 (152) 055-6118',
#   'Distinctio nihil nostrum nulla optio inventore eos libero adipisci vel quos '
#   'corporis quisquam dignissimos quibusdam quis pariatur ab sapiente eaque '
#   'adipisci odio saepe expedita reprehenderit.',
#   '1914-08-29',
#   1408,
#   '2022-02-20 18:31:41.266581',
#   '2022-02-20 18:31:41.266583',
#   '40.108.246.125'),
#  (2739,
#   'Elizabeth Gonzalez',
#   'theresa24@yahoo.com',
#   '038 Thomas Terrace Apt. 617\nBakerberg, PE L9R1R5',
#   'Webbview',
#   'Yukon Territory',
#   'Swaziland',
#   '1-352-277-5760',
#   'Voluptatibus architecto consequatur corrupti dolorem rem non vero vitae '
#   'accusantium dolor omnis debitis facere maxime quis facere aspernatur '
#   'nesciunt a.',
#   '2018-11-14',
#   2194,
#   '2022-02-20 18:31:41.267419',
#   '2022-02-20 18:31:41.267420',
#   '94.171.62.43'),
#  (2740,
#   'Laura Williams',
#   'maldonadoanna@hill.com',
#   '912 Melissa Cape\nMartinezside, QC H4P2X3',
#   'Robleschester',
#   'New Brunswick',
#   'Jordan',
#   '1-816-027-3969',
#   'Facilis voluptatem magnam sunt mollitia doloremque incidunt error nisi '
#   'voluptatum vitae nobis repellendus voluptas vero rem illum quibusdam optio '
#   'eum neque tempora laborum vel eaque quod eos molestiae repudiandae quaerat '
#   'possimus ratione beatae voluptates molestiae natus.',
#   '1920-06-25',
#   1876,
#   '2022-02-20 18:31:41.268426',
#   '2022-02-20 18:31:41.268427',
#   '99.64.18.25'),
#  (2741,
#   'Christopher Moore',
#   'stevenfrederick@gmail.com',
#   '790 Gilbert Cliffs\nLake Gary, PE G6N1T7',
#   'South Timothymouth',
#   'Northwest Territories',
#   'Korea',
#   '555-923-0947 x034',
#   'Quos laborum fuga unde unde blanditiis voluptas molestias est quaerat '
#   'quibusdam fugiat maxime eligendi quod fugiat suscipit tempora debitis neque '
#   'minus.',
#   '2010-03-05',
#   1874,
#   '2022-02-20 18:31:41.269321',
#   '2022-02-20 18:31:41.269322',
#   '18.104.196.30'),
#  (2742,
#   'Eric Adams',
#   'johnsonmisty@gmail.com',
#   '10780 Alexander Ports Suite 149\nJoefurt, NL H2K 6E4',
#   'West Heather',
#   'Northwest Territories',
#   'Norway',
#   '957-531-8140',
#   'Repudiandae tempore explicabo accusantium nihil quidem repellat nisi hic in '
#   'necessitatibus ab eum nihil dolorum tempore nulla sunt inventore impedit '
#   'illum placeat illo harum voluptatem quidem repellendus officiis autem '
#   'velit.',
#   '1989-08-03',
#   1028,
#   '2022-02-20 18:31:41.270212',
#   '2022-02-20 18:31:41.270213',
#   '95.249.21.209'),
#  (2743,
#   'Jennifer Lucero',
#   'oweaver@riley.net',
#   '3537 Garcia Valleys\nMichelleborough, BC N3G8N4',
#   'South Catherineberg',
#   'Manitoba',
#   'Portugal',
#   '1 (454) 040-3990',
#   'Vel perspiciatis modi veritatis odit quo non corporis quo exercitationem '
#   'accusamus velit ipsa saepe nisi temporibus tempore maxime quas est '
#   'repellendus voluptatem earum quod quasi quae eos nesciunt quos ipsum '
#   'suscipit amet labore at itaque.',
#   '1935-10-05',
#   1057,
#   '2022-02-20 18:31:41.271329',
#   '2022-02-20 18:31:41.271330',
#   '88.28.251.24'),
#  (2744,
#   'Alyssa Stewart',
#   'dgonzales@ruiz-gray.com',
#   '299 Stephen Knolls\nSouth Lisa, ON H5V9R7',
#   'Lewisberg',
#   'Alberta',
#   'Korea',
#   '638-694-5440',
#   'Dolores dolorem rerum itaque accusantium officia quisquam quae nobis a '
#   'eaque molestias facere harum id adipisci perspiciatis veritatis atque ab '
#   'cumque magnam dolor ad.',
#   '2021-06-23',
#   1025,
#   '2022-02-20 18:31:41.272345',
#   '2022-02-20 18:31:41.272347',
#   '166.240.172.79'),
#  (2745,
#   'Bruce Sandoval',
#   'briandominguez@hotmail.com',
#   '89946 Gilbert Meadows\nNew Shelbyhaven, ON N8B 1V4',
#   'Kirkland',
#   'Nova Scotia',
#   'Nicaragua',
#   '1-187-738-0603',
#   'At maiores nisi tenetur illum consequatur veniam autem dolor minus corporis '
#   'nisi veniam id labore itaque est excepturi nulla itaque excepturi tempora '
#   'dolor voluptate sit qui quae quos fugiat sequi.',
#   '2006-07-03',
#   1219,
#   '2022-02-20 18:31:41.273255',
#   '2022-02-20 18:31:41.273270',
#   '162.10.95.56'),
#  (2746,
#   'Christine Parks',
#   'mjackson@gmail.com',
#   '482 Miller Estates Suite 469\nMeghanville, NL J9T 2S3',
#   'Port Michael',
#   'Nova Scotia',
#   'Isle of Man',
#   '(134) 624-8563 x558',
#   'Tempora tenetur ad sint accusamus sint reprehenderit magni recusandae '
#   'quisquam magni saepe magni debitis ipsa adipisci nemo nisi ex laboriosam '
#   'non nemo nobis neque repellendus architecto a harum eaque autem perferendis '
#   'nisi eos labore at reprehenderit officia sint ad.',
#   '1946-09-02',
#   1892,
#   '2022-02-20 18:31:41.274105',
#   '2022-02-20 18:31:41.274106',
#   '99.8.177.31'),
#  (2747,
#   'Steven Harrell',
#   'ryansmith@gmail.com',
#   '5935 Carr Island Suite 574\nSimschester, PE A6E 3A8',
#   'South Keith',
#   'Newfoundland and Labrador',
#   'Nicaragua',
#   '(321) 798-0997',
#   'Quia quam laboriosam quibusdam laudantium ipsam consectetur illum '
#   'voluptatem soluta accusamus iure nihil reprehenderit ducimus deleniti in '
#   'repudiandae expedita minus quae incidunt voluptatem nobis officia '
#   'consectetur harum earum odit explicabo maxime labore labore recusandae '
#   'consectetur veritatis ab quibusdam magnam.',
#   '1942-07-22',
#   1843,
#   '2022-02-20 18:31:41.275007',
#   '2022-02-20 18:31:41.275008',
#   '12.58.85.205'),
#  (2748,
#   'Michael Pruitt',
#   'obarnett@young-bradshaw.com',
#   '166 Phillip Highway\nPort Stevehaven, PE M9G5J9',
#   'Webbburgh',
#   'Newfoundland and Labrador',
#   'Israel',
#   '(430) 766-3003',
#   'Sed alias reprehenderit itaque suscipit quam esse laborum blanditiis '
#   'impedit minima ex dignissimos veniam quidem et quae est numquam unde '
#   'architecto veniam animi autem veniam sequi.',
#   '1924-07-15',
#   1347,
#   '2022-02-20 18:31:41.276023',
#   '2022-02-20 18:31:41.276024',
#   '76.51.228.15'),
#  (2749,
#   'Erica Sherman',
#   'mortiz@hotmail.com',
#   '08280 Grant Haven\nNorth Tylershire, ON S5J 2P7',
#   'Calhounland',
#   'Alberta',
#   'Cape Verde',
#   '(923) 173-5628',
#   'Accusamus nostrum quia corporis vero quo similique officia harum sapiente '
#   'quos deserunt tempora repellat alias laborum praesentium rerum maxime '
#   'consectetur accusantium ipsum eaque voluptate iusto laudantium eius dicta '
#   'tempora odit provident ipsa voluptatibus exercitationem voluptatum tempora '
#   'ab corporis aperiam assumenda magni.',
#   '1936-03-04',
#   1852,
#   '2022-02-20 18:31:41.276856',
#   '2022-02-20 18:31:41.276857',
#   '216.114.93.118'),
#  (2750,
#   'Tammy Mullen',
#   'zhangthomas@middleton.info',
#   '066 Harris Mall Apt. 183\nPachecoshire, MB K1R4A7',
#   'Reyesshire',
#   'Newfoundland and Labrador',
#   'Ukraine',
#   '472-063-2309',
#   'Suscipit quibusdam blanditiis enim numquam eum eius eveniet voluptatibus '
#   'minima harum vitae dicta provident possimus quis corrupti magni hic '
#   'temporibus necessitatibus placeat aliquid assumenda accusantium ea rerum '
#   'temporibus.',
#   '1985-11-19',
#   1079,
#   '2022-02-20 18:31:41.277901',
#   '2022-02-20 18:31:41.277902',
#   '205.159.29.170'),
#  (2751,
#   'Ross Ramirez',
#   'juliemitchell@rodgers.org',
#   '17668 Doyle Extension\nMichaelshire, YT M8K 6N4',
#   'Cynthiahaven',
#   'New Brunswick',
#   'Central African Republic',
#   '1-882-956-4108',
#   'Ipsam accusantium consequatur eveniet beatae beatae hic praesentium iusto '
#   'natus quod perferendis ullam nemo sit dolor odit sed.',
#   '1942-11-03',
#   1806,
#   '2022-02-20 18:31:41.279043',
#   '2022-02-20 18:31:41.279044',
#   '123.237.6.208'),
#  (2752,
#   'Kristen Copeland',
#   'zarmstrong@roberts.info',
#   '88094 Brock Lights Suite 246\nChandlerfort, QC A1G8E2',
#   'New Christina',
#   'Ontario',
#   'Argentina',
#   '760 929 7101',
#   'Reprehenderit pariatur dolore doloremque consectetur tempora sint sunt '
#   'illum accusamus iste omnis doloremque incidunt quasi delectus aliquid fugit '
#   'officia rerum veritatis praesentium corrupti eligendi optio numquam commodi '
#   'ab vero architecto animi enim fuga ad autem mollitia nisi reiciendis libero '
#   'quod voluptates quam.',
#   '1998-10-30',
#   1166,
#   '2022-02-20 18:31:41.280245',
#   '2022-02-20 18:31:41.280246',
#   '147.53.159.62'),
#  (2753,
#   'Rachel Jenkins',
#   'mary23@rowland.com',
#   '95966 Stephanie Bridge\nWashingtonchester, NU T2S6M7',
#   'Matthewhaven',
#   'Ontario',
#   'Finland',
#   '(704) 744-7697',
#   'Mollitia nihil eaque odit doloremque id ab reprehenderit asperiores '
#   'asperiores architecto ipsa in sed eos sapiente libero adipisci.',
#   '1945-05-26',
#   1367,
#   '2022-02-20 18:31:41.281349',
#   '2022-02-20 18:31:41.281350',
#   '59.168.13.218'),
#  (2754,
#   'Brian Jones',
#   'gjarvis@howard.net',
#   '970 Kristina Village Suite 771\nRacheltown, QC H9C4Y8',
#   'Edwardshaven',
#   'Yukon Territory',
#   'Palestinian Territory',
#   '938-531-2968',
#   'Maiores et quisquam explicabo sunt fuga libero rerum totam quidem dolorem '
#   'blanditiis a explicabo praesentium excepturi sed asperiores amet quibusdam '
#   'nostrum eligendi voluptatum consequatur quos repudiandae provident.',
#   '1988-09-21',
#   1705,
#   '2022-02-20 18:31:41.282729',
#   '2022-02-20 18:31:41.282730',
#   '117.69.48.102'),
#  (2755,
#   'Yolanda Kelley',
#   'kingjennifer@garcia-carroll.com',
#   '187 Snow Islands\nKathrynton, BC E6K 4L4',
#   'Danielborough',
#   'Nova Scotia',
#   'Afghanistan',
#   '239 934 2361',
#   'Quo molestias doloribus repellendus explicabo doloribus expedita natus '
#   'soluta provident nisi hic quisquam sequi consectetur sapiente quam suscipit '
#   'id non minus quae autem at consequuntur atque nemo corporis repudiandae '
#   'dolorum.',
#   '1908-09-06',
#   1257,
#   '2022-02-20 18:31:41.283897',
#   '2022-02-20 18:31:41.283898',
#   '205.235.74.206'),
#  (2756,
#   'Lisa Love',
#   'johnny14@hotmail.com',
#   '209 James Cape Suite 820\nWest Juliaton, YT B9K 4S4',
#   'Durhamland',
#   'Prince Edward Island',
#   'Israel',
#   '681 866 0971',
#   'Incidunt quis labore delectus numquam explicabo minima enim repellat quam '
#   'nesciunt vero dolores culpa facere optio exercitationem quae asperiores '
#   'ducimus iure alias ex distinctio.',
#   '1910-07-17',
#   1036,
#   '2022-02-20 18:31:41.284764',
#   '2022-02-20 18:31:41.284765',
#   '107.160.230.33'),
#  (2757,
#   'Laura Wolf',
#   'jamie85@jennings.com',
#   '98555 Flores Meadow Apt. 331\nLake David, NS R4H8C9',
#   'Lake Tammychester',
#   'Ontario',
#   'Cape Verde',
#   '827.834.4350',
#   'Tempora in eius velit necessitatibus quae dicta architecto nesciunt quae '
#   'fugiat cum minima deleniti iste numquam fuga blanditiis quibusdam '
#   'aspernatur accusantium at tempora blanditiis dolor accusantium culpa eaque '
#   'molestiae esse.',
#   '1958-07-01',
#   2487,
#   '2022-02-20 18:31:41.285894',
#   '2022-02-20 18:31:41.285895',
#   '55.89.95.219'),
#  (2758,
#   'Ryan Ford',
#   'lesliewilson@choi-rodriguez.info',
#   '903 Ross Mountains Suite 817\nNew Alanmouth, NB T1L 9H2',
#   'Paceport',
#   'Northwest Territories',
#   'Tanzania',
#   '(563) 639-8678 x063',
#   'Doloribus similique consequuntur eveniet fuga quas labore reiciendis modi '
#   'minus incidunt labore veniam porro eum quidem earum vero eaque laboriosam '
#   'voluptatem quisquam.',
#   '2020-04-26',
#   1938,
#   '2022-02-20 18:31:41.287003',
#   '2022-02-20 18:31:41.287004',
#   '124.76.198.234'),
#  (2759,
#   'Nicole Thomas',
#   'edonovan@chavez.com',
#   '18728 Knox Shoals\nNew Erin, BC K4G 1A6',
#   'Teresaburgh',
#   'New Brunswick',
#   'Venezuela',
#   '583.065.0109',
#   'Officiis nesciunt repudiandae ex quisquam deserunt explicabo asperiores '
#   'mollitia eum vitae sequi animi veritatis iusto eum eum laudantium optio '
#   'reprehenderit earum quae perferendis nesciunt harum ea enim natus dicta hic '
#   'labore laborum nemo totam minima inventore natus totam placeat in.',
#   '1930-08-06',
#   2326,
#   '2022-02-20 18:31:41.287957',
#   '2022-02-20 18:31:41.287958',
#   '4.228.78.50'),
#  (2760,
#   'Timothy Hendricks',
#   'mirandahernandez@yahoo.com',
#   '966 Good Dale Suite 628\nEast Stacey, NU B9K 6M8',
#   'Emilyfort',
#   'Newfoundland and Labrador',
#   'Dominica',
#   '530-066-9764 x446',
#   'Recusandae reprehenderit ipsum cum voluptates sed eum expedita quod iure '
#   'similique atque doloribus dolore dolores rem dolorem facilis dolore '
#   'aspernatur velit eius accusamus exercitationem recusandae nobis adipisci '
#   'sed odio nulla optio ad quidem laborum iusto modi ullam.',
#   '1965-01-06',
#   1806,
#   '2022-02-20 18:31:41.288889',
#   '2022-02-20 18:31:41.288890',
#   '86.137.11.63'),
#  (2761,
#   'Kurt Sawyer',
#   'aharris@mccann.com',
#   '975 Hoover Neck Suite 577\nSheliaport, NU G4A 2V2',
#   'Wangbury',
#   'Newfoundland and Labrador',
#   'Western Sahara',
#   '+1 (751) 132-0719',
#   'Quo cumque similique accusantium quae repellat quasi nesciunt voluptate cum '
#   'earum et in sed voluptatum iusto sint expedita autem rerum adipisci.',
#   '1954-03-28',
#   1954,
#   '2022-02-20 18:31:41.290441',
#   '2022-02-20 18:31:41.290443',
#   '183.248.243.111'),
#  (2762,
#   'Andrew Cole',
#   'sweeneyjames@moore.com',
#   '90629 Andrew Ways\nSouth Adam, MB T7A2A2',
#   'South Anna',
#   'Nova Scotia',
#   'Costa Rica',
#   '+1 (971) 550-3137',
#   'Praesentium officia quisquam velit quas animi rerum et non necessitatibus '
#   'blanditiis voluptatum praesentium sunt maxime beatae beatae quis veniam '
#   'aperiam maxime tenetur asperiores corrupti ex ipsam error mollitia pariatur '
#   'aspernatur alias suscipit possimus veritatis repudiandae consequuntur.',
#   '1960-12-26',
#   2066,
#   '2022-02-20 18:31:41.291893',
#   '2022-02-20 18:31:41.291895',
#   '153.141.203.68'),
#  (2763,
#   'Sean West',
#   'grayricky@yahoo.com',
#   '513 Jimenez Estate Apt. 184\nLake Johnview, YT B1H4H4',
#   'South Bryanchester',
#   'Prince Edward Island',
#   'Serbia',
#   '990-370-0463',
#   'Nesciunt voluptate qui accusamus ducimus totam odit voluptas quisquam at '
#   'commodi similique sint doloremque ratione nobis voluptates adipisci odio '
#   'sit consectetur libero excepturi doloribus harum consectetur quo ea rem '
#   'consectetur autem iure consequuntur iure dolorum ut explicabo ea '
#   'exercitationem eaque rerum.',
#   '2013-12-22',
#   2112,
#   '2022-02-20 18:31:41.293058',
#   '2022-02-20 18:31:41.293059',
#   '143.155.46.32'),
#  (2764,
#   'Laurie Woodward',
#   'coxkaren@gmail.com',
#   '88504 Cortez Mountains\nEast Angela, NU H9R 3M4',
#   'New Andrew',
#   'Nunavut',
#   'Saint Kitts and Nevis',
#   '348-949-5526',
#   'Quidem ut aliquid fuga odit dolorum aliquam tempora eius fugit sapiente '
#   'placeat quas impedit sit ipsam sit a fugiat debitis nihil.',
#   '2013-02-23',
#   1304,
#   '2022-02-20 18:31:41.294559',
#   '2022-02-20 18:31:41.294562',
#   '167.20.20.70'),
#  (2765,
#   'Jason Pope',
#   'lisaknox@gmail.com',
#   '59790 Dickson Garden Suite 822\nNorth Brandon, YT C8Y 2B5',
#   'Rosefurt',
#   'Newfoundland and Labrador',
#   'Belgium',
#   '(955) 035-2320',
#   'Quae sequi fugiat magnam nesciunt unde voluptatum natus aperiam iusto nulla '
#   'exercitationem nisi quia eligendi quia dignissimos exercitationem molestiae '
#   'esse cupiditate dolorem odio magni dolore quaerat distinctio perferendis '
#   'dolore iste harum laboriosam quos sequi vitae alias enim voluptatem ad '
#   'earum.',
#   '1968-07-02',
#   1703,
#   '2022-02-20 18:31:41.296173',
#   '2022-02-20 18:31:41.296176',
#   '215.172.90.26'),
#  (2766,
#   'Shannon Baird',
#   'david25@swanson.net',
#   '53921 Kim Brook Apt. 980\nRuthport, MB G6C5M5',
#   'North Michael',
#   'Nunavut',
#   'Italy',
#   '(236) 717-3219 x775',
#   'Fugit praesentium commodi deserunt reiciendis rem maiores inventore '
#   'molestias quisquam delectus exercitationem fugit tempora deleniti '
#   'exercitationem dolorem blanditiis.',
#   '1957-06-07',
#   1677,
#   '2022-02-20 18:31:41.297459',
#   '2022-02-20 18:31:41.297460',
#   '63.25.131.59'),
#  (2767,
#   'Brian Singh',
#   'samantha16@preston.com',
#   '6173 Bowman Via Suite 987\nLake Victoriahaven, MB X2P1V4',
#   'Lake Jonathan',
#   'Ontario',
#   'United Arab Emirates',
#   '(587) 553-9884',
#   'Illum consequatur neque voluptates eveniet eum repellat similique eligendi '
#   'dolore fugit ratione ea enim quas sequi dolor ex nobis cupiditate '
#   'doloremque excepturi beatae libero vero assumenda saepe sed quaerat dolor.',
#   '2008-12-04',
#   1802,
#   '2022-02-20 18:31:41.298688',
#   '2022-02-20 18:31:41.298689',
#   '80.49.4.35'),
#  (2768,
#   'Ashley Garcia',
#   'greed@riggs.com',
#   '66028 Jones Ridges Apt. 193\nNew Williamville, PE P5B6L8',
#   'Cohenfort',
#   'Newfoundland and Labrador',
#   'Honduras',
#   '904.168.4303',
#   'Iusto eaque est modi qui unde tempore aut dolore et excepturi veniam '
#   'placeat amet perspiciatis in quam atque perspiciatis at distinctio odio '
#   'cupiditate illum numquam mollitia hic quibusdam quia quaerat delectus illum '
#   'officiis nam necessitatibus deleniti dolore delectus natus ex voluptates '
#   'voluptatibus.',
#   '1986-12-08',
#   2249,
#   '2022-02-20 18:31:41.300128',
#   '2022-02-20 18:31:41.300130',
#   '223.26.193.120'),
#  (2769,
#   'Dean Orozco',
#   'amber21@gmail.com',
#   '4656 Bradley Common\nWest William, NS L3B 4T4',
#   'Lake Tiffanyton',
#   'Quebec',
#   'Timor-Leste',
#   '821.533.6569',
#   'Sed cum vel deleniti labore cupiditate saepe hic nam numquam doloribus in '
#   'nam expedita quos quod soluta maiores velit atque nihil officia fugit culpa '
#   'atque architecto nam ipsam repudiandae saepe adipisci esse beatae libero '
#   'cumque eveniet.',
#   '1944-06-18',
#   2359,
#   '2022-02-20 18:31:41.301516',
#   '2022-02-20 18:31:41.301518',
#   '217.157.238.137'),
#  (2770,
#   'Edwin Perry',
#   'annette96@cross.biz',
#   '9483 Andrew Estate Suite 067\nShanebury, NL H2J 6B6',
#   'West Kathy',
#   'Nunavut',
#   'Costa Rica',
#   '808.031.3980',
#   'In tempore reprehenderit explicabo laboriosam est in quae ad iste ipsa '
#   'cumque neque quas natus iusto adipisci fuga placeat esse necessitatibus '
#   'sequi suscipit temporibus itaque sequi labore odit cum aliquid earum rem '
#   'vel optio rem fuga aliquid atque eos amet.',
#   '1939-12-23',
#   1500,
#   '2022-02-20 18:31:41.303057',
#   '2022-02-20 18:31:41.303058',
#   '133.124.11.5'),
#  (2771,
#   'Margaret Lopez',
#   'webbphilip@carey.org',
#   '21698 Townsend Summit\nHectorburgh, NL N8N 1B4',
#   'Adamfort',
#   'Northwest Territories',
#   'Palau',
#   '736-750-1274',
#   'Nulla accusamus ipsum nihil doloremque alias nam nulla quibusdam ullam '
#   'dolorem deleniti vero voluptatem eaque blanditiis velit earum corporis sed '
#   'sunt laboriosam eveniet autem repellat incidunt alias nemo quas enim '
#   'explicabo maiores molestiae eum doloribus.',
#   '2019-07-28',
#   1364,
#   '2022-02-20 18:31:41.304241',
#   '2022-02-20 18:31:41.304242',
#   '36.93.97.54'),
#  (2772,
#   'Mariah Bowen',
#   'xortega@orozco.com',
#   '8786 Eric Creek\nEast Ryan, NS H3B6B6',
#   'Greenshire',
#   'Saskatchewan',
#   'Andorra',
#   '(971) 386-6394',
#   'Inventore deserunt alias reprehenderit eaque dignissimos est rerum dolorum '
#   'laborum delectus vitae optio architecto error velit similique totam magni '
#   'quae minima soluta facere aperiam error.',
#   '1949-11-11',
#   2484,
#   '2022-02-20 18:31:41.305348',
#   '2022-02-20 18:31:41.305349',
#   '174.48.10.103'),
#  (2773,
#   'Tammy Wright',
#   'thomas95@miller-berg.org',
#   '806 Kimberly Falls Apt. 283\nEast Jacquelineton, NS N5E7T4',
#   'West Kristishire',
#   'Nunavut',
#   'Namibia',
#   '1-752-303-5697',
#   'Earum autem eligendi numquam voluptates quae nemo perspiciatis quos '
#   'adipisci deleniti nobis officia reiciendis alias esse dolorem dolor '
#   'excepturi et corporis expedita consequuntur velit repellendus architecto '
#   'nostrum nam.',
#   '1995-08-03',
#   2191,
#   '2022-02-20 18:31:41.306340',
#   '2022-02-20 18:31:41.306341',
#   '167.206.66.71'),
#  (2774,
#   'Charles Miller',
#   'anthonywong@farmer.biz',
#   '30605 Jennifer Pines Apt. 716\nWest Shellyton, NL T3H9H9',
#   'North Christopher',
#   'Quebec',
#   'Martinique',
#   '+1 (707) 783-7754',
#   'Debitis velit pariatur exercitationem ut natus necessitatibus magni itaque '
#   'necessitatibus tempore culpa deserunt unde aut nam nemo reiciendis dolorem '
#   'quidem.',
#   '1935-08-22',
#   1855,
#   '2022-02-20 18:31:41.307543',
#   '2022-02-20 18:31:41.307544',
#   '70.211.38.79'),
#  (2775,
#   'Angela Ryan',
#   'eolson@hotmail.com',
#   '76411 Ronald Cliff\nRyanhaven, NB T6M4S5',
#   'Port Christopherchester',
#   'British Columbia',
#   'Guernsey',
#   '1 (110) 602-0223',
#   'Laboriosam natus corrupti veniam cumque molestias deleniti ab molestiae '
#   'saepe architecto eveniet totam ad ab accusamus nostrum at aliquid tempora '
#   'et magnam vero non voluptas iste dolor impedit beatae aperiam quo pariatur '
#   'similique praesentium natus iusto quidem commodi eos officiis voluptate.',
#   '1958-09-20',
#   1537,
#   '2022-02-20 18:31:41.308386',
#   '2022-02-20 18:31:41.308387',
#   '36.179.14.65'),
#  (2776,
#   'Tanner Riley',
#   'leejenna@fuentes.org',
#   '300 Christensen Fords\nPorterberg, NL V5K9V7',
#   'West Brandi',
#   'New Brunswick',
#   'Uzbekistan',
#   '886 858 2602',
#   'Ab voluptates voluptas molestias possimus consequuntur repellat porro '
#   'laudantium a qui sequi pariatur architecto molestiae nisi suscipit animi '
#   'qui earum dignissimos possimus debitis atque ullam esse aspernatur '
#   'blanditiis qui.',
#   '1998-07-18',
#   2431,
#   '2022-02-20 18:31:41.309390',
#   '2022-02-20 18:31:41.309391',
#   '120.102.59.162'),
#  (2777,
#   'Linda Roberts',
#   'jessica53@chapman-joseph.com',
#   '9224 Ashley Highway\nAnthonyhaven, NS K7E2N5',
#   'Martinland',
#   'Manitoba',
#   'Albania',
#   '604-719-0211',
#   'Expedita voluptates commodi mollitia impedit modi assumenda repellat '
#   'consectetur eveniet consequatur sed vero mollitia neque minus officia in '
#   'dolores quidem similique sed neque optio porro velit deserunt voluptatibus '
#   'enim maxime voluptates est nisi debitis cupiditate consequatur esse omnis '
#   'praesentium debitis.',
#   '1917-09-19',
#   2172,
#   '2022-02-20 18:31:41.310662',
#   '2022-02-20 18:31:41.310663',
#   '66.185.52.121'),
#  (2778,
#   'Joshua Brown',
#   'sburns@gmail.com',
#   '670 Baker Trail\nDavisstad, NT B6T 3B2',
#   'Port Feliciaville',
#   'Manitoba',
#   'Western Sahara',
#   '593.004.5262',
#   'Tenetur ad natus nostrum voluptatibus quo laudantium inventore sapiente et '
#   'velit asperiores quaerat praesentium animi ipsam facilis est possimus quae '
#   'sunt.',
#   '1931-01-09',
#   1618,
#   '2022-02-20 18:31:41.311729',
#   '2022-02-20 18:31:41.311731',
#   '93.245.70.234'),
#  (2779,
#   'Carlos Alexander',
#   'cgraves@gmail.com',
#   '1189 Jacob Pine\nPort Jon, BC P6K 8B8',
#   'Kathrynfurt',
#   'Prince Edward Island',
#   'Lesotho',
#   '(739) 410-4205',
#   'Ab maiores officiis quam omnis quod suscipit libero enim nisi possimus '
#   'nobis iste voluptate a tenetur praesentium quo praesentium labore sunt vero '
#   'neque vel temporibus laboriosam dolor aliquam.',
#   '1969-05-22',
#   2169,
#   '2022-02-20 18:31:41.312779',
#   '2022-02-20 18:31:41.312780',
#   '153.182.190.73'),
#  (2780,
#   'Linda Wolfe DDS',
#   'kimberly24@franco.com',
#   '1394 Megan Pike Suite 789\nPort Peter, NS V5M8K6',
#   'Lake Tanya',
#   'British Columbia',
#   'Hong Kong',
#   '+1 (121) 112-6688',
#   'Praesentium maxime molestias fugiat nobis blanditiis nihil natus quisquam '
#   'nemo ea eaque reprehenderit quis porro sunt aspernatur id porro beatae '
#   'nulla cum nihil quibusdam totam aperiam recusandae rem libero accusamus '
#   'recusandae ullam iste est.',
#   '1958-02-21',
#   1459,
#   '2022-02-20 18:31:41.313760',
#   '2022-02-20 18:31:41.313762',
#   '32.58.216.131'),
#  (2781,
#   'Nathan Hardin',
#   'paul99@payne-morales.com',
#   '071 Elizabeth Plains\nNorth Jessica, ON V1X 8T4',
#   'Jessicaland',
#   'Newfoundland and Labrador',
#   'Dominica',
#   '484 839 9158',
#   'Debitis sit atque fugiat ipsam velit animi sit iusto voluptates earum '
#   'ratione maxime quae aliquid eius dolorum facere repudiandae recusandae esse '
#   'pariatur labore omnis neque inventore consequatur maxime similique '
#   'similique in labore magni ut laudantium alias pariatur.',
#   '1970-02-11',
#   2311,
#   '2022-02-20 18:31:41.314732',
#   '2022-02-20 18:31:41.314733',
#   '7.163.38.8'),
#  (2782,
#   'Susan Cook',
#   'grimesmichael@gmail.com',
#   '8057 Susan Ferry\nAnneland, QC C2X 6K8',
#   'Nicoleburgh',
#   'Prince Edward Island',
#   'Samoa',
#   '(223) 968-5539 x785',
#   'Deserunt distinctio accusantium cumque numquam consectetur deserunt quos '
#   'atque ad quis commodi hic aperiam consequuntur consequatur commodi minima '
#   'aliquam cupiditate rerum voluptatum consequuntur suscipit rerum ipsum '
#   'veritatis tempora possimus voluptas laboriosam explicabo consectetur optio '
#   'nesciunt expedita doloribus cum exercitationem.',
#   '1958-03-24',
#   1900,
#   '2022-02-20 18:31:41.315634',
#   '2022-02-20 18:31:41.315636',
#   '162.6.11.251'),
#  (2783,
#   'Robert Jones',
#   'hwilliamson@gmail.com',
#   '4361 Brandon Rapids\nEast Jacquelinechester, NT K2P7J7',
#   'Johnland',
#   'Quebec',
#   'Martinique',
#   '534-118-2107',
#   'Repudiandae eaque adipisci hic itaque enim itaque quis occaecati hic optio '
#   'impedit voluptates omnis eveniet iste saepe dicta vitae ab eaque beatae '
#   'facere hic nisi deleniti quas vero molestias facere suscipit natus nihil '
#   'vitae doloremque.',
#   '2016-04-01',
#   2476,
#   '2022-02-20 18:31:41.316469',
#   '2022-02-20 18:31:41.316470',
#   '186.94.213.17'),
#  (2784,
#   'Bradley Garrett',
#   'nelsondavid@hotmail.com',
#   '5338 Huerta Walks Suite 012\nGonzalesfort, NU B6P 3K7',
#   'Lake Mistyland',
#   'British Columbia',
#   'Saint Martin',
#   '356.848.4746',
#   'Eveniet doloremque iure harum voluptate atque veritatis ullam sunt quam '
#   'aspernatur minima inventore in odio eum asperiores hic eveniet minima nam '
#   'dolor odio aliquid delectus soluta quis in corrupti dolores laboriosam ut '
#   'sit sint.',
#   '1948-07-09',
#   2477,
#   '2022-02-20 18:31:41.317408',
#   '2022-02-20 18:31:41.317409',
#   '85.210.89.240'),
#  (2785,
#   'Patricia Ortiz',
#   'spencebrittany@gmail.com',
#   '3497 Ralph Stravenue Apt. 466\nWest Williamchester, BC A7M3H1',
#   'Paulmouth',
#   'Manitoba',
#   'Syrian Arab Republic',
#   '(365) 249-5141 x814',
#   'Minima nihil possimus fugit nostrum perspiciatis saepe quod harum facere '
#   'totam praesentium nobis facilis quis rerum id iure quia est neque eveniet '
#   'ipsa porro blanditiis culpa qui maiores deleniti suscipit quas animi '
#   'quaerat impedit dolores.',
#   '1934-02-14',
#   1269,
#   '2022-02-20 18:31:41.318299',
#   '2022-02-20 18:31:41.318300',
#   '24.61.37.191'),
#  (2786,
#   'Craig Wallace',
#   'hannah26@hotmail.com',
#   '7287 Jennifer Lane\nNorth Johnmouth, ON A5P8V1',
#   'East Wanda',
#   'Newfoundland and Labrador',
#   'Tuvalu',
#   '1 (910) 429-4449',
#   'Rem ratione ab magni quos quae repellat officiis rerum qui dolore incidunt '
#   'dolorem quia maiores enim nemo libero dolorem reiciendis praesentium '
#   'eligendi officia id.',
#   '1908-02-13',
#   2052,
#   '2022-02-20 18:31:41.319083',
#   '2022-02-20 18:31:41.319084',
#   '184.118.7.56'),
#  (2787,
#   'Emily Edwards',
#   'snowdavid@herrera.com',
#   '761 Stephanie Landing\nLynnborough, NL B6E1C3',
#   'Gutierrezview',
#   'British Columbia',
#   'Benin',
#   '1 (400) 572-7430',
#   'Consequatur accusamus provident omnis mollitia veritatis at alias eaque '
#   'tempora esse corporis numquam optio soluta ad doloremque consequuntur natus '
#   'fugit nisi omnis fuga incidunt aperiam fugiat exercitationem itaque placeat '
#   'eveniet.',
#   '1929-03-01',
#   1320,
#   '2022-02-20 18:31:41.320242',
#   '2022-02-20 18:31:41.320243',
#   '31.5.71.39'),
#  (2788,
#   'Guy Knight',
#   'james04@holland.com',
#   '6517 Moore Forge Apt. 820\nSouth Sara, YT S5G 3A3',
#   'Lake Kathyton',
#   'Northwest Territories',
#   'Guam',
#   '449-067-2153 x684',
#   'Architecto rem repellendus repellat consequuntur odit neque exercitationem '
#   'praesentium asperiores sit unde praesentium tempora inventore culpa '
#   'doloremque a accusantium consequatur veritatis adipisci impedit officiis '
#   'esse ullam dicta vitae dolore repellat commodi autem.',
#   '1929-10-02',
#   1295,
#   '2022-02-20 18:31:41.321328',
#   '2022-02-20 18:31:41.321329',
#   '180.158.196.132'),
#  (2789,
#   'Jonathan Hoffman',
#   'bwashington@yahoo.com',
#   '0539 Hall Locks Apt. 094\nNew Michael, NS V3B9B1',
#   'Leeton',
#   'New Brunswick',
#   'Belize',
#   '1-669-965-1846',
#   'Officia perferendis nostrum aliquam quaerat recusandae magnam natus '
#   'molestiae debitis labore a tempora ipsum eum quasi non culpa magni dolore '
#   'corporis sunt consequatur iure iste recusandae.',
#   '1967-07-07',
#   1946,
#   '2022-02-20 18:31:41.322208',
#   '2022-02-20 18:31:41.322209',
#   '164.61.66.246'),
#  (2790,
#   'Charles King',
#   'christian46@hotmail.com',
#   '96189 Eric Valley Suite 216\nOwensview, NB J9L3Y8',
#   'East Mariashire',
#   'Prince Edward Island',
#   'Eritrea',
#   '(714) 509-1232',
#   'Sapiente eligendi velit deserunt cum praesentium aperiam quasi eum amet '
#   'debitis mollitia consequatur dolores odio fugiat at voluptate eaque amet '
#   'amet odit velit sapiente qui et natus animi veniam aut consequuntur '
#   'doloremque fugit dolor minus.',
#   '1973-05-04',
#   1223,
#   '2022-02-20 18:31:41.323035',
#   '2022-02-20 18:31:41.323036',
#   '186.128.164.236'),
#  (2791,
#   'Jeffrey Parks',
#   'brucerichardson@ayala.com',
#   '63886 Mills Court\nPort Jacob, AB P1S 2J5',
#   'North Nicholas',
#   'Newfoundland and Labrador',
#   'Chile',
#   '357.313.0460',
#   'Nostrum suscipit ipsa et veritatis dicta architecto vitae similique commodi '
#   'architecto sunt pariatur incidunt modi placeat beatae optio neque molestias '
#   'quod delectus labore enim quasi ab a culpa porro distinctio dolores sed '
#   'voluptatum.',
#   '1942-12-17',
#   1965,
#   '2022-02-20 18:31:41.324164',
#   '2022-02-20 18:31:41.324166',
#   '194.171.36.7'),
#  (2792,
#   'Christopher Moss',
#   'usmith@rowe.com',
#   '0291 Sydney Mount\nAlbertstad, NU X2T9B1',
#   'Bellview',
#   'Saskatchewan',
#   'Sao Tome and Principe',
#   '+1 (599) 445-9070',
#   'Distinctio corporis necessitatibus ad excepturi eveniet delectus vel in '
#   'neque hic illum modi consequatur aperiam nulla aspernatur quo veritatis sed '
#   'totam dolore vel cumque ut asperiores.',
#   '1959-04-21',
#   1101,
#   '2022-02-20 18:31:41.325243',
#   '2022-02-20 18:31:41.325244',
#   '93.189.221.74'),
#  (2793,
#   'Kyle Roth',
#   'bramos@hotmail.com',
#   '134 Amanda Trail Apt. 312\nLake Amy, NB J5P 5A1',
#   'West Pamelachester',
#   'Prince Edward Island',
#   'Burkina Faso',
#   '(165) 068-6931',
#   'Libero enim quod pariatur possimus fugit asperiores magni asperiores '
#   'perferendis labore voluptatum illum voluptas itaque quam eius molestias '
#   'numquam molestiae animi sunt magni hic sint dolores inventore optio omnis '
#   'et mollitia earum quae in fugit fuga nisi exercitationem temporibus '
#   'possimus.',
#   '1925-12-03',
#   1657,
#   '2022-02-20 18:31:41.326063',
#   '2022-02-20 18:31:41.326064',
#   '186.151.165.79'),
#  (2794,
#   'Jason Sullivan',
#   'cmejia@chavez.org',
#   '38266 Jean Ports\nNew Tracy, QC P6V4Y8',
#   'South Darryl',
#   'British Columbia',
# ...
#   'Congo',
#   '1 (853) 790-5818',
#   'Repudiandae laboriosam odit quibusdam optio corporis sint nam corrupti vel '
#   'quas vitae dolores officia delectus velit incidunt ratione beatae dolores '
#   'dolore amet deserunt recusandae quidem commodi quisquam tempora alias '
#   'laboriosam ut sapiente suscipit nesciunt alias neque veniam temporibus '
#   'recusandae.',
#   '1940-12-19',
#   1441,
#   '2022-02-20 18:31:41.543225',
#   '2022-02-20 18:31:41.543226',
#   '194.65.160.196'),
#  (2978,
#   'Teresa Brown',
#   'jennifergonzalez@ross.com',
#   '77947 Michael Highway\nNew Nicoleberg, NT G6A 6A2',
#   'Johnport',
#   'Prince Edward Island',
#   'Saint Helena',
#   '224-622-0300 x778',
#   'Minima error quia eveniet facilis aliquid sunt earum corporis placeat ipsa '
#   'veritatis culpa natus possimus officiis doloribus repellat odit quam '
#   'excepturi aspernatur ut sed saepe quia nobis fugit voluptates libero '
#   'repellat voluptates.',
#   '1994-10-09',
#   2296,
#   '2022-02-20 18:31:41.544298',
#   '2022-02-20 18:31:41.544300',
#   '72.7.77.249'),
#  (2979,
#   'Philip Rios',
#   'pbenitez@gmail.com',
#   '13357 Dakota Crossing Suite 652\nBrownburgh, PE C4E8P9',
#   'West Elizabethport',
#   'Manitoba',
#   'Niger',
#   '1 (483) 231-4163',
#   'Enim autem maxime repellendus incidunt aspernatur error dolorem eligendi '
#   'est voluptatem magnam rerum inventore accusantium nostrum tempore '
#   'asperiores nesciunt sed inventore soluta.',
#   '1995-06-06',
#   1267,
#   '2022-02-20 18:31:41.545188',
#   '2022-02-20 18:31:41.545189',
#   '159.81.154.53'),
#  (2980,
#   'Caitlin Guzman',
#   'briankane@patel.net',
#   '6281 Torres Isle Suite 706\nSheltonberg, NS P1H 3M3',
#   'South Alexchester',
#   'Manitoba',
#   'Venezuela',
#   '752.197.4732',
#   'Beatae quam explicabo officiis sunt hic quas inventore similique explicabo '
#   'est nesciunt facilis culpa quo error voluptatum recusandae hic doloribus '
#   'laboriosam iusto ducimus.',
#   '1942-11-16',
#   1710,
#   '2022-02-20 18:31:41.546287',
#   '2022-02-20 18:31:41.546289',
#   '181.231.218.25'),
#  (2981,
#   'Mark Long',
#   'james33@gmail.com',
#   '8750 Zachary Ridge Apt. 574\nMyersmouth, YT Y4C 1T9',
#   'Lake Thomas',
#   'Manitoba',
#   'Saint Helena',
#   '402.316.6588',
#   'Numquam laborum libero in laborum occaecati amet necessitatibus accusamus '
#   'accusamus consequatur necessitatibus commodi laborum beatae nisi similique '
#   'dicta incidunt sed dolor occaecati laborum atque quaerat voluptates '
#   'officiis eos eius.',
#   '1952-09-19',
#   2006,
#   '2022-02-20 18:31:41.547256',
#   '2022-02-20 18:31:41.547272',
#   '165.110.34.230'),
#  (2982,
#   'Nicole Cervantes',
#   'maria66@good.com',
#   '986 Lopez Plaza Suite 524\nSouth Sandra, MB L2A2Y3',
#   'Lake Michelleborough',
#   'Newfoundland and Labrador',
#   'Tuvalu',
#   '365-794-0794',
#   'Praesentium perferendis quo saepe quia modi consectetur earum eum quia cum '
#   'consectetur aut reiciendis ratione quaerat quas eos expedita repellendus '
#   'consectetur eaque veritatis voluptate quod labore totam.',
#   '2002-12-23',
#   1452,
#   '2022-02-20 18:31:41.548514',
#   '2022-02-20 18:31:41.548515',
#   '109.91.125.158'),
#  (2983,
#   'Sarah Zimmerman',
#   'bflores@chavez.biz',
#   '0522 Marie Glen\nLeahstad, ON K2R 5V4',
#   'North Sharonland',
#   'Nunavut',
#   'Brazil',
#   '899 939 1866',
#   'Accusantium temporibus nisi doloremque quisquam est voluptatum atque fuga '
#   'dolorum sunt vel cupiditate expedita iure quo illum earum error culpa rem.',
#   '1955-10-08',
#   2464,
#   '2022-02-20 18:31:41.549898',
#   '2022-02-20 18:31:41.549899',
#   '208.242.249.183'),
#  (2984,
#   'Julia Jackson',
#   'sheilahester@walls.info',
#   '389 Williams Crest\nLake Edward, MB H8A8B9',
#   'Barbaraberg',
#   'Quebec',
#   'Oman',
#   '+1 (703) 085-9299',
#   'Maiores asperiores repudiandae libero corporis ex vel dolor ut omnis '
#   'mollitia optio nesciunt ratione consequatur enim quis sequi iure rerum odit '
#   'suscipit autem officia neque vitae fugiat.',
#   '2005-05-31',
#   2483,
#   '2022-02-20 18:31:41.551078',
#   '2022-02-20 18:31:41.551079',
#   '33.134.231.114'),
#  (2985,
#   'Gary Mcmillan',
#   'fjackson@martinez-harvey.info',
#   '264 Jason Loaf\nWest Jenna, AB E3T 2H9',
#   'Wellsland',
#   'British Columbia',
#   'Jersey',
#   '540 938 9575',
#   'Natus a blanditiis animi rem harum quidem ad corrupti voluptatibus maiores '
#   'fugiat inventore optio architecto aliquid ea minus beatae quia '
#   'necessitatibus rerum quidem quasi quas exercitationem placeat nulla.',
#   '1999-01-23',
#   1718,
#   '2022-02-20 18:31:41.552112',
#   '2022-02-20 18:31:41.552113',
#   '152.255.15.211'),
#  (2986,
#   'Casey Webb',
#   'gfranklin@hotmail.com',
#   '70658 Dylan Turnpike\nEast Brittanytown, SK X4V3T8',
#   'New Ryan',
#   'Yukon Territory',
#   'Mali',
#   '450 603 4979',
#   'Ad consectetur dolore autem quam reprehenderit at eligendi quidem qui optio '
#   'deleniti cumque ratione ipsa ullam at at repellendus facilis quaerat enim '
#   'voluptatibus natus ducimus.',
#   '1982-04-19',
#   2181,
#   '2022-02-20 18:31:41.552956',
#   '2022-02-20 18:31:41.552957',
#   '34.245.246.136'),
#  (2987,
#   'Sandra Salinas',
#   'simonlaura@gmail.com',
#   '39178 Tammie Loaf\nNew Charlesfurt, NT X6H6E1',
#   'Lake Williamborough',
#   'Nunavut',
#   'China',
#   '1-736-461-6743',
#   'Neque nihil neque sed omnis tenetur molestiae dicta quia labore unde '
#   'placeat velit soluta non animi libero inventore quod.',
#   '2007-12-16',
#   1804,
#   '2022-02-20 18:31:41.553845',
#   '2022-02-20 18:31:41.553846',
#   '31.214.99.173'),
#  (2988,
#   'Edward Gomez',
#   'townsendmichele@poole.com',
#   '5175 Williams Bypass Apt. 515\nJacobmouth, PE J1B 8E8',
#   'South Elizabeth',
#   'Prince Edward Island',
#   'Bhutan',
#   '550.862.5299',
#   'Optio cumque tempore facilis perspiciatis autem porro suscipit voluptatem '
#   'eaque veniam pariatur odio delectus omnis tempore nisi corporis saepe '
#   'quidem saepe maiores.',
#   '1964-03-21',
#   1505,
#   '2022-02-20 18:31:41.555026',
#   '2022-02-20 18:31:41.555028',
#   '117.77.227.45'),
#  (2989,
#   'Sarah Love',
#   'lharris@hotmail.com',
#   '19775 Brown Cove Suite 045\nEmilymouth, BC R7B 5X7',
#   'New Tracychester',
#   'Prince Edward Island',
#   'Poland',
#   '850-705-0863',
#   'Cum eligendi minus labore magni saepe earum sed perspiciatis accusantium '
#   'velit explicabo itaque debitis aliquam laborum debitis sequi.',
#   '1961-07-26',
#   2202,
#   '2022-02-20 18:31:41.555925',
#   '2022-02-20 18:31:41.555926',
#   '28.249.128.94'),
#  (2990,
#   'Anthony Johnson',
#   'kennedymonica@yahoo.com',
#   '585 Long Points\nRamirezstad, NL A6Y4G7',
#   'New Stuartton',
#   'Prince Edward Island',
#   'Eritrea',
#   '1-835-770-6453',
#   'Animi ipsum temporibus tempora cum similique aliquam nobis sunt quod '
#   'officia quaerat repellendus iste tempore sit vero voluptas soluta quo omnis '
#   'nulla exercitationem iure distinctio.',
#   '1930-11-13',
#   1806,
#   '2022-02-20 18:31:41.556845',
#   '2022-02-20 18:31:41.556846',
#   '206.32.202.181'),
#  (2991,
#   'Justin Wright',
#   'ballrussell@hotmail.com',
#   '11577 Christina Field Apt. 852\nDoylefurt, YT E4S 7B1',
#   'East Jennifer',
#   'Northwest Territories',
#   'Saint Vincent and the Grenadines',
#   '1 (216) 431-8614',
#   'Quis nemo tenetur aliquam et deserunt voluptas commodi quis facere quos '
#   'maxime quam tempore corporis non quod aspernatur voluptas alias eaque '
#   'tenetur voluptate distinctio.',
#   '1935-11-11',
#   1342,
#   '2022-02-20 18:31:41.557771',
#   '2022-02-20 18:31:41.557772',
#   '128.93.41.120'),
#  (2992,
#   'Cynthia Raymond',
#   'michaelpearson@gmail.com',
#   '0166 Juan Heights\nEast Teresa, NS A7B6K6',
#   'South Nicholaston',
#   'Quebec',
#   'Macedonia',
#   '+1 (537) 832-6544',
#   'Molestias et adipisci hic eligendi incidunt esse ipsum dicta harum non '
#   'rerum doloremque eveniet error minima amet veniam occaecati vel magnam '
#   'consequatur veritatis amet dignissimos consectetur aliquid unde at in '
#   'inventore exercitationem nostrum nesciunt aspernatur itaque harum dolor '
#   'nisi sed.',
#   '2013-03-17',
#   1752,
#   '2022-02-20 18:31:41.558671',
#   '2022-02-20 18:31:41.558672',
#   '100.35.183.139'),
#  (2993,
#   'Dr. Michael Caldwell Jr.',
#   'lindahernandez@jackson.com',
#   '27585 Sergio Summit Apt. 031\nCowanhaven, NT B4M4E1',
#   'West Michaelton',
#   'Saskatchewan',
#   'United Arab Emirates',
#   '840-233-9453',
#   'Quo consectetur accusamus temporibus dignissimos modi facere vero placeat '
#   'soluta corporis aut cumque delectus velit alias earum laborum omnis '
#   'cupiditate doloribus molestiae harum reprehenderit atque eligendi nobis '
#   'eveniet maxime cum.',
#   '1966-09-21',
#   1921,
#   '2022-02-20 18:31:41.559892',
#   '2022-02-20 18:31:41.559893',
#   '166.173.248.187'),
#  (2994,
#   'Bethany Martin',
#   'qmiller@wilson.org',
#   '8760 Linda Points\nSouth Timothyborough, NT J3V1T1',
#   'Brownbury',
#   'Saskatchewan',
#   'Qatar',
#   '(131) 192-0943',
#   'Atque totam veniam eaque qui neque illum commodi natus itaque porro '
#   'necessitatibus quod nisi hic provident distinctio libero nam velit tempora '
#   'voluptatibus veniam accusantium odio pariatur officiis doloremque magnam '
#   'quidem.',
#   '1922-03-06',
#   1768,
#   '2022-02-20 18:31:41.560862',
#   '2022-02-20 18:31:41.560863',
#   '104.250.5.116'),
#  (2995,
#   'James Wong',
#   'calvin13@hotmail.com',
#   '89551 Orr Rapid\nThomasstad, NU H2M 3K9',
#   'West Colleen',
#   'British Columbia',
#   'Kazakhstan',
#   '1 (563) 120-8138',
#   'Nesciunt eum nulla possimus voluptatem minus amet rerum sapiente laudantium '
#   'molestiae totam incidunt possimus delectus distinctio hic fugiat quod '
#   'molestias tenetur sunt iusto quo in fuga error similique quis beatae '
#   'laboriosam nesciunt sit laboriosam quisquam.',
#   '1993-08-10',
#   1451,
#   '2022-02-20 18:31:41.561713',
#   '2022-02-20 18:31:41.561715',
#   '32.228.162.141'),
#  (2996,
#   'Brandon Smith',
#   'humphreymichael@wallace.com',
#   '3557 Brett Spring Apt. 242\nJustinmouth, NS G1T 7H6',
#   'Kristenview',
#   'Quebec',
#   'Burundi',
#   '(426) 506-7813 x001',
#   'Eaque facere ratione accusantium velit facilis vel blanditiis nemo ex harum '
#   'error doloribus hic dignissimos accusantium reiciendis dolorum eveniet ipsa '
#   'quaerat aperiam adipisci accusamus accusantium reiciendis quo accusamus '
#   'labore ullam illum sit assumenda aspernatur consectetur qui optio quibusdam '
#   'delectus temporibus atque.',
#   '2021-04-24',
#   1265,
#   '2022-02-20 18:31:41.562756',
#   '2022-02-20 18:31:41.562757',
#   '151.249.51.8'),
#  (2997,
#   'Shane Rodriguez',
#   'victorperry@yahoo.com',
#   '116 Marcia Turnpike\nTheresaview, NS M1C 2V9',
#   'Villanuevaville',
#   'New Brunswick',
#   'Uganda',
#   '1 (801) 474-1695',
#   'Velit repellat nam ipsam eum possimus incidunt consectetur est facere ex '
#   'soluta sed delectus ad debitis velit occaecati blanditiis et unde quasi '
#   'voluptatum numquam maiores excepturi mollitia non enim dolorum doloremque '
#   'veritatis cum.',
#   '2010-05-25',
#   1239,
#   '2022-02-20 18:31:41.563694',
#   '2022-02-20 18:31:41.563695',
#   '31.214.245.88'),
#  (2998,
#   'Kimberly Hall',
#   'tyler06@mitchell-smith.com',
#   '24902 Brandon Trail Suite 666\nNew Josephtown, NS M8X7L2',
#   'Duncantown',
#   'Yukon Territory',
#   'Vanuatu',
#   '+1 (867) 436-5773',
#   'Vel ab explicabo assumenda natus est maiores est inventore a voluptatem '
#   'doloremque est quas rem itaque aut cupiditate distinctio nobis natus eum a '
#   'quae tempora ipsa eos quis possimus expedita nemo doloremque libero '
#   'doloribus deserunt ratione.',
#   '1911-07-31',
#   2406,
#   '2022-02-20 18:31:41.565796',
#   '2022-02-20 18:31:41.565799',
#   '69.45.138.92'),
#  (2999,
#   'Jason Sloan',
#   'mfrench@hardy.com',
#   '675 Patricia Alley Apt. 744\nWest Michaelbury, AB K3K 7X6',
#   'Johnport',
#   'British Columbia',
#   'Saint Martin',
#   '1 (489) 834-0839',
#   'Voluptates animi dolorum architecto assumenda ipsa quisquam vel aliquam '
#   'tempora voluptates fugit sapiente ipsam labore magnam eos ducimus iste '
#   'fugit numquam earum alias iusto eum.',
#   '1932-09-18',
#   1797,
#   '2022-02-20 18:31:41.567148',
#   '2022-02-20 18:31:41.567150',
#   '15.78.14.116'),
#  (3000,
#   'Rachel Reed',
#   'bryan21@olson.org',
#   '555 Haynes Ports\nParsonsville, MB M7H3J2',
#   'Donaldview',
#   'Manitoba',
#   'Greenland',
#   '+1 (321) 513-0826',
#   'Quos vitae distinctio consequuntur nulla esse dolores recusandae dicta '
#   'adipisci expedita autem similique laborum eum fuga dolor ratione ipsa '
#   'aperiam quia quidem officiis exercitationem.',
#   '1927-12-14',
#   1521,
#   '2022-02-20 18:31:41.568284',
#   '2022-02-20 18:31:41.568285',
#   '105.112.219.56'),
#  (3001,
#   'Heather Santos',
#   'bponce@pineda.com',
#   '4656 Andrew Underpass Suite 835\nCollinsborough, PE R5J1K2',
#   'Lake Raymond',
#   'Manitoba',
#   'Indonesia',
#   '(255) 853-5122 x572',
#   'Sequi ipsum labore unde quisquam iusto autem fugiat odit quae commodi saepe '
#   'dicta quam et corporis quasi debitis ab rerum placeat aspernatur '
#   'dignissimos quae dicta ut repellendus tempora ducimus vero similique.',
#   '1971-05-21',
#   2036,
#   '2022-02-20 18:31:41.570229',
#   '2022-02-20 18:31:41.570230',
#   '2.13.232.18'),
#  (3002,
#   'Heather Brown',
#   'warrenjanet@gmail.com',
#   '74808 Hannah Junction Suite 480\nEast Allen, ON P7K 5S6',
#   'Lake Luis',
#   'Prince Edward Island',
#   'Kyrgyz Republic',
#   '644.584.9154',
#   'Iste ipsa officia veritatis molestias consequuntur ipsam assumenda qui '
#   'accusamus cupiditate asperiores tempore rerum ipsam minima tenetur iure '
#   'temporibus iste natus inventore maxime quia odit illo similique doloribus '
#   'facilis in ducimus optio consequatur.',
#   '1959-03-19',
#   2479,
#   '2022-02-20 18:31:41.571943',
#   '2022-02-20 18:31:41.571945',
#   '41.186.59.159'),
#  (3003,
#   'Dillon Hickman',
#   'nicholsondiana@yahoo.com',
#   '1021 Delgado Fork\nCamposburgh, YT C5X2R5',
#   'Crystalfort',
#   'Prince Edward Island',
#   'Turks and Caicos Islands',
#   '782 581 8687',
#   'Dolor voluptatum magnam exercitationem ad enim magni quod praesentium '
#   'laborum mollitia explicabo tempora at molestias earum officia voluptate '
#   'magnam necessitatibus corporis saepe placeat reprehenderit culpa '
#   'repellendus id debitis ipsa non laborum doloribus culpa.',
#   '1928-04-24',
#   1257,
#   '2022-02-20 18:31:41.573095',
#   '2022-02-20 18:31:41.573096',
#   '90.182.182.206'),
#  (3004,
#   'Jason Stewart',
#   'smithlori@hotmail.com',
#   '6191 Keith Cliffs\nSouth Elizabeth, MB N8R 1S4',
#   'Grahamland',
#   'Nunavut',
#   'Austria',
#   '1 (585) 076-0437',
#   'Non aliquam ex eligendi deleniti deleniti a aspernatur qui dicta id '
#   'explicabo dolor ex quibusdam culpa sint praesentium quam hic praesentium ut '
#   'fugiat deleniti inventore rem velit earum in atque aliquid cupiditate '
#   'similique enim fugiat dolorum.',
#   '1963-01-25',
#   2493,
#   '2022-02-20 18:31:41.574170',
#   '2022-02-20 18:31:41.574172',
#   '82.245.29.115'),
#  (3005,
#   'Brandon Herrera',
#   'turnerjames@hotmail.com',
#   '98028 Mendez Rapids\nMelissaport, PE J8C3K7',
#   'East Catherinetown',
#   'Yukon Territory',
#   'Belgium',
#   '444 111 3661',
#   'Sequi similique hic amet enim aperiam vel omnis unde sapiente illo '
#   'distinctio dolorum pariatur ullam consequuntur recusandae vero porro '
#   'officiis soluta animi consequuntur quisquam aliquid asperiores mollitia '
#   'eaque commodi neque harum culpa eos mollitia.',
#   '1963-10-22',
#   1586,
#   '2022-02-20 18:31:41.575362',
#   '2022-02-20 18:31:41.575363',
#   '177.212.56.76'),
#  (3006,
#   'Matthew Flores',
#   'dwhitney@gray.net',
#   '26533 Mcdonald Trail Suite 066\nHayesmouth, NU M9P7K3',
#   'South Aliciaton',
#   'Nova Scotia',
#   'Bulgaria',
#   '(807) 459-9428',
#   'Unde quod nostrum maiores quas ipsum fugiat nobis iusto eum quo '
#   'reprehenderit sint magnam occaecati quibusdam molestias doloremque nesciunt '
#   'facere rerum ex eligendi perspiciatis earum natus iure a non quaerat '
#   'voluptates animi amet doloremque saepe.',
#   '2000-12-06',
#   1786,
#   '2022-02-20 18:31:41.576824',
#   '2022-02-20 18:31:41.576825',
#   '58.123.144.53')]
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-40-84a2d553dc15> in <module>()
#      51
#      52
# ---> 53 myConnection.commit()
#      54 myConnection.close()
#      55 #Ideally, you will want to create a loop that will iterate 1000 times,
#
# OperationalError: database is locked

# %% [markdown]
# Finally, the last step,
# Using the code block below, combined with what you have learned above, and the Lecture notes,
# Craft a SQL Query that will return the `name` of no more than `20` `people` with a `heatmap` greater than `1500`

# %%
import sqlite3
import pprint
#Retreive the Connection object
myConnection = sqlite3.connect('social_network.db')

#Once we have a Connection object, we can generate a Cursor object, and use that to run our SQL Queries
myCursor = myConnection.cursor()

selectStatement = """SELECT name, heatmap FROM people WHERE heatmap > 1500 LIMIT 20"""

myCursor.execute(selectStatement)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-6b77034b0fbb> in <module>()
#      15
#      16 myCursor.execute("SELECT * FROM people")
# ---> 17 pprint(myCursor.fetchall())
#
# TypeError: 'module' object is not callable

# %% [markdown]
# Your submission will contain, as usual, a link to your completed colab notebook, but in addition to that, you will download a copy of your social_network.db file and upload it to D2L. To download the file, right click it from the Files menu on the left of the Notebook.
